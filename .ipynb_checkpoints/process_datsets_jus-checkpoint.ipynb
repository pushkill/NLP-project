# %%
import pandas as pd
import nltk
import os

# %%
kaggle_datasets_path = 'C:\\Users\\hladn\\FAKS\\magisterij\\Natural language processing\\assignment\\NLP-project\\datasets\\kaggle'
word_datasets_preprocessed_path = 'C:\\Users\\hladn\\FAKS\\magisterij\\Natural language processing\\assignment\\NLP-project\\datasets\\word_datasets_preprocessed'

# %% [markdown]
# ### process dataset https://www.kaggle.com/c/jigsaw-toxic-comment-classification-challenge/data
# select records with labels: insult, threat, obscene

# %%
toxic_comments_classification_challenge = 'train_toxic_comment_classification_challenge.csv'
dataset_path = os.path.join(kaggle_datasets_path, toxic_comments_classification_challenge)
df = pd.read_csv(dataset_path)

# %%
df[df['severe_toxic']==1]
# Out:
#                       id                                       comment_text  \
# 6       0002bcb3da6cb337       COCKSUCKER BEFORE YOU PISS AROUND ON MY WORK
# 55      0020e7119b96eeeb  Stupid peace of shit stop deleting my stuff as...
# 181     006e87872c8b370c  you are a stupid fuck \n\nand your mother's cu...
# 442     01208d2b76624130       Hi \n\nIm a fucking bitch.\n\n50.180.208.181
# 579     018663f910e0bfe6  What a motherfucking piece of crap those fuckh...
# ...                  ...                                                ...
# 159096  f871b05d4caa6f20  You filthy, stinking crow! \n\nI am back! Dirt...
# 159099  f885a3e2d779342e  now\n\nyou fucking pathetic moron. \n\ncc:  Ji...
# 159281  fb726deec64157bd  LoL!! \n\nyou're GAY!! you will never know how...
# 159312  fbf20e312cd4a78d  Walter Mercado \n\nAntonio, quite frankly, you...
# 159400  fd052883fa6a8697  Shalom \n\nSemite, get the fuck out of here. I...
#
# ...

# %%
toxic_comments_classification_challenge = 'train_toxic_comment_classification_challenge.csv'
dataset_path = os.path.join(kaggle_datasets_path, toxic_comments_classification_challenge)
df = pd.read_csv(dataset_path)

df_insult = df[df['insult']==1].copy()
df_insult = df_insult.drop(columns=['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate', 'id'])
df_insult['label'] = 'insult'
df_insult = df_insult.rename(columns={"comment_text": "text"})
df_insult.to_csv(os.path.join(word_datasets_preprocessed_path, 'insult.csv'), index = False)

df_threat = df[df['threat']==1].copy()
df_threat = df_threat.drop(columns=['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate', 'id'])
df_threat['label'] = 'threat'
df_threat = df_threat.rename(columns={"comment_text": "text"})
df_threat.to_csv(os.path.join(word_datasets_preprocessed_path, 'threat.csv'), index = False)

df_obscene = df[df['obscene']==1].copy()
df_obscene = df_obscene.drop(columns=['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate', 'id'])
df_obscene['label'] = 'obscene'
df_obscene = df_obscene.rename(columns={"comment_text": "text"})
df_obscene.to_csv(os.path.join(word_datasets_preprocessed_path, 'obscene.csv'), index = False)

df_severe_toxic = df[df['severe_toxic']==1].copy()
df_severe_toxic = df_severe_toxic.drop(columns=['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate', 'id'])
df_severe_toxic['label'] = 'severe_toxic'
df_severe_toxic = df_severe_toxic.rename(columns={"comment_text": "text"})
df_severe_toxic.to_csv(os.path.join(word_datasets_preprocessed_path, 'severe_toxic.csv'), index = False)

df_identity_hate = df[df['identity_hate']==1].copy()
df_identity_hate = df_identity_hate.drop(columns=['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate', 'id'])
df_identity_hate['label'] = 'identity_hate'
df_identity_hate = df_identity_hate.rename(columns={"comment_text": "text"})
df_identity_hate.to_csv(os.path.join(word_datasets_preprocessed_path, 'identity_hate.csv'), index = False)

#df_obscene

# %% [markdown]
# ### process davidson dataset: https://arxiv.org/abs/1703.04009 available at https://github.com/t-davidson/hate-speech-and-offensive-language
# we extract labels: hate speech(hateful) and offensive
# class label for majority of labeling users. 0 - hate speech 1 - offensive language 2 - neither

# %%
cwd = os.getcwd()
davidson_dataset_path = 'davidson.csv'
dataset_path = os.path.join(os.path.join(cwd, 'datasets'), davidson_dataset_path)
df = pd.read_csv(dataset_path)

# %%
df[df['class']==0]

df_hateful = df[df['class']==0].copy()
df_hateful = df_hateful.drop(columns=['Unnamed: 0', 'count', 'hate_speech', 'offensive_language', 'neither', 'class'])
df_hateful['label'] = 'hateful'
df_hateful = df_hateful.rename(columns={"tweet": "text"})
df_hateful.to_csv(os.path.join(word_datasets_preprocessed_path, 'hateful.csv'), index = False)
df_hateful

df_offensive = df[df['class']==1].copy()
df_offensive = df_offensive.drop(columns=['Unnamed: 0', 'count', 'hate_speech', 'offensive_language', 'neither', 'class'])
df_offensive['label'] = 'offensive'
df_offensive = df_offensive.rename(columns={"tweet": "text"})
df_offensive.to_csv(os.path.join(word_datasets_preprocessed_path, 'offensive.csv'), index = False)

df_hateful
# Out:
#                                                     text    label
# 85     "@Blackman38Tide: @WhaleLookyHere @HowdyDowdy1...  hateful
# 89     "@CB_Baby24: @white_thunduh alsarabsss" hes a ...  hateful
# 110    "@DevilGrimz: @VigxRArts you're fucking gay, b...  hateful
# 184    "@MarkRoundtreeJr: LMFAOOOO I HATE BLACK PEOPL...  hateful
# 202    "@NoChillPaz: "At least I'm not a nigger" http...  hateful
# ...                                                  ...      ...
# 24576                this guy is the biggest faggot omfg  hateful
# 24685  which one of these names is more offensive kik...  hateful
# 24751         you a pussy ass nigga and I know it nigga.  hateful
# 24776                                 you're all niggers  hateful
# 24777  you're such a retard i hope you get type 2 dia...  hateful
#
# [1430 rows x 2 columns]

# %% [markdown]
# ### process dataset https://arxiv.org/abs/2012.15761 available at https://www.kaggle.com/usharengaraju/dynamically-generated-hate-speech-dataset?select=2020-12-31-DynamicallyGeneratedHateDataset-entries-v0.1.csv
# we use label animosity to get texts for key term hostile

# %%
cwd = os.getcwd()
dynamic_generated_dataset_path = '2020-12-31-DynamicallyGeneratedHateDataset-entries-v0.1.csv'
dataset_path = os.path.join(os.path.join(cwd, 'datasets'), dynamic_generated_dataset_path)
df = pd.read_csv(dataset_path)

# %%
df_hostile = df[df['type']=='animosity'].copy()
df_hostile = df_hostile.drop(columns=['Unnamed: 0', 'id', 'label', 'type', 'model_wrong', 'db.model_preds', 'status', 'round', 'split', 'annotator'])
df_hostile['label'] = 'hostile'
#df_hostile = df_hostile.rename(columns={"tweet": "text"})
df_hostile.to_csv(os.path.join(word_datasets_preprocessed_path, 'hostile.csv'), index = False)
df_hostile
# Out:
#                                                     text    label
# 6076      There are many muslims on my street it's scary  hostile
# 6086     there are many immigrants on my street, help!!!  hostile
# 6106   There are many chinese people living on this s...  hostile
# 6110   There are many chinese people in this area now...  hostile
# 6124   There are many aboriginal people living in thi...  hostile
# ...                                                  ...      ...
# 36394  Don't be so angry or upset if you personally h...  hostile
# 36398  mental illness has something to do with it, ev...  hostile
# 36402  Rape and Sexual violence is undeniably a massi...  hostile
# 36416  I fucking love being gay, mostly because I'm n...  hostile
# 36419  He won't get any money now because those black...  hostile
#
# [2377 rows x 2 columns]

# %% [markdown]
# ### process dataset from http://ceur-ws.org/Vol-2517/T3-1.pdf available at https://hasocfire.github.io/hasoc/2019/dataset.html (we use english_dataset.tsv)
# HATE-hate speech, OFFN-offensive, PRFN- profane

# %%
cwd = os.getcwd()
dynamic_generated_dataset_path = 'english_dataset_hasoc2019.tsv'
dataset_path = os.path.join(os.path.join(cwd, 'datasets'), dynamic_generated_dataset_path)
df = pd.read_csv(dataset_path, sep='\t')

# %%
df_profane = df[df['task_2']=='PRFN'].copy()
df_profane = df_profane.drop(columns=['text_id', 'task_1', 'task_2', 'task_3'])
df_profane['label'] = 'profane'
#df_profane = df_profane.rename(columns={"tweet": "text"})
df_profane.to_csv(os.path.join(word_datasets_preprocessed_path, 'profane.csv'), index = False)
df_profane

df_hateful = df[df['task_2']=='HATE'].copy()
df_hateful = df_hateful.drop(columns=['text_id', 'task_1', 'task_2', 'task_3'])
df_hateful['label'] = 'hateful'
#df_hateful = df_hateful.rename(columns={"tweet": "text"})
df_hateful.to_csv(os.path.join(word_datasets_preprocessed_path, 'hateful_2.csv'), index = False)


df_offensive = df[df['task_2']=='OFFN'].copy()
df_offensive = df_offensive.drop(columns=['text_id', 'task_1', 'task_2', 'task_3'])
df_offensive['label'] = 'offensive'
#df_offensive = df_offensive.rename(columns={"tweet": "text"})
df_offensive.to_csv(os.path.join(word_datasets_preprocessed_path, 'offensive_2.csv'), index = False)

# %% [markdown]
# ### process dataset from  https://www.aclweb.org/anthology/N16-2013.pdf available at https://github.com/DataforGoodIsrael/DetectHateSpeech
# extract labels: sexiast and racist

# %%
cwd = os.getcwd()
dynamic_generated_dataset_path = 'waseem_hovy2016.csv'
dataset_path = os.path.join(os.path.join(cwd, 'datasets'), dynamic_generated_dataset_path)
df = pd.read_csv(dataset_path, sep='\t')

# %%
df[df['Label']=='sexism']
# Out:
#                 Tweet_ID      Previous     User_ID  \
# 1939  571022970140778496           NaN  2756873076
# 1940  575595460993286145           NaN  2826054068
# 1941  410574843688415232  4.105327e+17   930620467
# 1942  534506865930297344           NaN   930620467
# 1943  563363714401705986  5.633608e+17  2756873076
# ...                  ...           ...         ...
# 5082  575957907193274368           NaN   108948616
# 5083  566989876693045248           NaN  2756873076
# 5084  402275391701647361  4.017598e+17   930620467
# 5085  575597174945280000           NaN   261162002
# 5086  418191905881464833  4.174100e+17   930620467
#
#                                                    Text   Label
# 1939  RT @catfreq: @MT8_9 @JimyIsAHappyBoy @BoycottB...  sexism
# 1940  RT @daniel_kaye: It's not Kat and Andre - it's...  sexism
# 1941  *yawn* @Eminent_dude Im sorry but women cannot...  sexism
# 1942  RT @Vonta624: I'm not sexist but I'd never get...  sexism
# ...

# %%
df_racist = df[df['Label']=='racism'].copy()
df_racist = df_racist.drop(columns=['Tweet_ID', 'Previous', 'User_ID', 'Label'])
df_racist['label'] = 'racist'
df_racist = df_racist.rename(columns={"Text": "text"})
df_racist.to_csv(os.path.join(word_datasets_preprocessed_path, 'racist.csv'), index = False)

df_sexist = df[df['Label']=='sexism'].copy()
df_sexist = df_sexist.drop(columns=['Tweet_ID', 'Previous', 'User_ID', 'Label'])
df_sexist['label'] = 'sexist'
df_sexist = df_sexist.rename(columns={"Text": "text"})
df_sexist.to_csv(os.path.join(word_datasets_preprocessed_path, 'sexist.csv'), index = False)
df_sexist
# Out:
#                                                    text   label
# 1939  RT @catfreq: @MT8_9 @JimyIsAHappyBoy @BoycottB...  sexist
# 1940  RT @daniel_kaye: It's not Kat and Andre - it's...  sexist
# 1941  *yawn* @Eminent_dude Im sorry but women cannot...  sexist
# 1942  RT @Vonta624: I'm not sexist but I'd never get...  sexist
# 1943  @Ryan140GG Nope. Adoption and safe haven. She ...  sexist
# ...                                                 ...     ...
# 5082  #MKR that wiped that horrible smile off Kat's ...  sexist
# 5083  RT @Oneiorosgrip: #adviceforyoungfeminists Lea...  sexist
# 5084  RT @Keltonsexy250 I'm concerned for the girls ...  sexist
# 5085  RT @melbsonmymind: NO. NO NO NO NO NO NO NO. G...  sexist
# 5086  A hit with 5-year-olds @adnan_bahatti55 Don't ...  sexist
#
# [3148 rows x 2 columns]

# %%
sfawfwef

# %%
df
df_sexist = df[df['Label']=='sexism'].copy()
df_sexist = df_sexist.drop(columns=['Tweet_ID', 'Previous', 'User_ID', 'Label'])
df_sexist['label'] = 'sexist'
df_sexist = df_sexist.rename(columns={"Text": "text"})
df_sexist.to_csv(os.path.join(word_datasets_preprocessed_path, 'sexist.csv'), index = False)
df_sexist
# Out:
#                                                    text   label
# 1939  RT @catfreq: @MT8_9 @JimyIsAHappyBoy @BoycottB...  sexist
# 1940  RT @daniel_kaye: It's not Kat and Andre - it's...  sexist
# 1941  *yawn* @Eminent_dude Im sorry but women cannot...  sexist
# 1942  RT @Vonta624: I'm not sexist but I'd never get...  sexist
# 1943  @Ryan140GG Nope. Adoption and safe haven. She ...  sexist
# ...                                                 ...     ...
# 5082  #MKR that wiped that horrible smile off Kat's ...  sexist
# 5083  RT @Oneiorosgrip: #adviceforyoungfeminists Lea...  sexist
# 5084  RT @Keltonsexy250 I'm concerned for the girls ...  sexist
# 5085  RT @melbsonmymind: NO. NO NO NO NO NO NO NO. G...  sexist
# 5086  A hit with 5-year-olds @adnan_bahatti55 Don't ...  sexist
#
# [3148 rows x 2 columns]
