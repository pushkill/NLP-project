# %%
import pandas as pd
import seaborn as sns
import numpy as np
import nltk
import os
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.stem import SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE
from sklearn.manifold import MDS
from sklearn.decomposition import PCA
import matplotlib.patheffects as PathEffects
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import string
import re
from collections import Counter


nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hladn\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hladn\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hladn\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
cwd = os.getcwd()
df = pd.read_csv( os.path.join(cwd, 'full_dataset_all_labels.csv'))
stop_words=set(stopwords.words('english') + list(string.punctuation))
stop_words.add('rt') # add word rt (meaning retweet) to stop words
df = pd.read_csv('full_dataset_all_labels.csv')
#df = df.sample(10000)

# %%
i=21750
print(df['text'].iloc[i])
#print(df['tokenized_text'].iloc[i])
df[df['text'].str.contains("<USER> that's not how it works")]
# Out:
# RETARD
#
# I'ts my flippen opinion anyways and how about get a life intead of reporting peoplego get laid you stupid gay virgin
#                                              text   label
# 77205  <USER> that's not how it works bitch <URL>  vulgar

# %%
def print_some_texts(columns, df):
    text_idxs = [47, 7240, 7241, 8013, 14500, 16500, 16304, 18300,  21750, 34036, 45159, 71920]
    for i in text_idxs:
        for column in columns:
            print(df[column].iloc[i])
#print_some_texts(['text'])

def tokenize(text):
    #print(text)
    text = preprocess_text(text)
    #print(text)
    tokens = word_tokenize(text)
    filtered_tokens = []
    # Filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation). (adapted from lab example)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            if token not in stop_words and len(token) > 2:
                filtered_tokens.append(token)
    return filtered_tokens
    

def preprocess_text(text):
    text = re.sub(r"http\S+", " ", text)            # remove urls
    text = re.sub("@[A-Za-z0-9]+","", text)         # remove twitter handle
    text = re.sub("&amp;","", text)                  # &amp; is a special character for ampersand
    text = re.sub('<USER>', '', text)               # remove '<USER>' as there are some such strings as user or url is masked with this string
    text = re.sub('<URL>', '', text)
    text = text.lower() 
    text = re.sub('[^a-zA-Z]', ' ', text)           # Remove punctuations
    text = text.lower()                             # Convert to lowercase
    text = re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)#remove tags
    text = re.sub("(\\d|\\W)+"," ",text)            # remove special characters and digits
    return text
    
    
def stemming(tokens):
    stemmer = SnowballStemmer("english")
    stems = [stemmer.stem(token) for token in tokens]
    return stems

def lemmatizing(tokens):
    lemmatizer = WordNetLemmatizer()
    lemmas = [lemmatizer.lemmatize(token) for token in tokens]
    return lemmas

# %%
df['preprocessed_text']=df['text'].apply(preprocess_text)
df['tokenized_text']= df['preprocessed_text'].apply(tokenize) 

df['stems']= df['tokenized_text'].apply(stemming) 
df['lemmas']= df['tokenized_text'].apply(lemmatizing)

# %%
df[df['label']=='offensive']
# Out:
#                                                     text      label  \
# 38423  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...  offensive
# 38424  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...  offensive
# 38425  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...  offensive
# 38426  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...  offensive
# 38427  !!!!!!!!!!!!!!!!!!"@T_Madison_x: The shit just...  offensive
# ...                                                  ...        ...
# 58059  @briantylercohen @mattgaetz is such a #doucheb...  offensive
# 58060  @ImranKhanPTI if u and ur govt have little sha...  offensive
# 58061  @TheRealOJ32 You’re really stabbin...er, grabb...  offensive
# 58062  #DoctorsFightBack  Will 'The Mad n Irrational ...  offensive
# 58063  #ShiningIndia #educatedindia or more like RUND...  offensive
#
#                                        preprocessed_text  \
# 38423   rt boy dats cold tyga dwn bad for cuffin dat ...
# 38424   rt dawg rt you ever fuck a bitch and she star...
# 38425         rt g anderson based she look like a tranny
# 38426   rt the shit you hear about me might be true o...
# 38427   madison x the shit just blows me claim you so...
# ...                                                  ...
# 58059   is such a douchebag he would have really gone...
# 58060   if u and ur govt have little shame and believ...
# 58061   you re really stabbin er grabbin straws here ...
# 58062   doctorsfightback will the mad n irrational di...
# 58063   shiningindia educatedindia or more like rundi...
#
#                                           tokenized_text  \
# 38423  [boy, dats, cold, tyga, dwn, bad, cuffin, dat,...
# 38424  [dawg, ever, fuck, bitch, start, cry, confused...
# 38425              [anderson, based, look, like, tranny]
# 38426  [shit, hear, might, true, might, faker, bitch,...
# 38427  [madison, shit, blows, claim, faithful, somebo...
# ...                                                  ...
# 58059  [douchebag, would, really, gone, places, third...
# 58060  [govt, little, shame, believe, humanity, act, ...
# 58061  [really, stabbin, grabbin, straws, away, murde...
# 58062  [doctorsfightback, mad, irrational, dictator, ...
# 58063  [shiningindia, educatedindia, like, rundia, pl...
#
#                                                    stems  \
# 38423  [boy, dat, cold, tyga, dwn, bad, cuffin, dat, ...
# 38424  [dawg, ever, fuck, bitch, start, cri, confus, ...
# 38425               [anderson, base, look, like, tranni]
# 38426  [shit, hear, might, true, might, faker, bitch,...
# 38427  [madison, shit, blow, claim, faith, somebodi, ...
# ...                                                  ...
# 58059  [douchebag, would, realli, gone, place, third,...
# 58060  [govt, littl, shame, believ, human, act, inhum...
# 58061    [realli, stabbin, grabbin, straw, away, murder]
# 58062  [doctorsfightback, mad, irrat, dictat, mamata,...
# 58063  [shiningindia, educatedindia, like, rundia, pl...
#
#                                                   lemmas
# 38423  [boy, dat, cold, tyga, dwn, bad, cuffin, dat, ...
# 38424  [dawg, ever, fuck, bitch, start, cry, confused...
# 38425              [anderson, based, look, like, tranny]
# 38426  [shit, hear, might, true, might, faker, bitch,...
# 38427  [madison, shit, blow, claim, faithful, somebod...
# ...                                                  ...
# 58059  [douchebag, would, really, gone, place, third,...
# 58060  [govt, little, shame, believe, humanity, act, ...
# 58061  [really, stabbin, grabbin, straw, away, murderer]
# 58062  [doctorsfightback, mad, irrational, dictator, ...
# 58063  [shiningindia, educatedindia, like, rundia, pl...
#
# [19641 rows x 6 columns]

# %%
#print_some_texts(['text','preprocessed_text',  'tokenized_text', 'stems'], df)

# %%
def labels_most_frequent_words(df, label, column, n_words = 10, visualise = False):
    # returns sorted list (decreasing) of n most frequent words for a label
    all_words_list=df[df['label']==label][column].sum()
    all_words_count = dict(Counter(all_words_list))
    words_freq = [(word, all_words_count[word]) for word in all_words_count]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    if visualise:
        top_n_words_freq = words_freq[:n_words]
        x,y=map(list,zip(*top_n_words_freq))
        sns.barplot(x=y, y=x)
        
    #print(words_freq)
    return words_freq[:n_words]

# %%
words_freq = labels_most_frequent_words(df, label='vulgar', column='lemmas', n_words = 20, visualise = True)
#print(words_freq)

# %%
# df with most frequent/significant/important words for each label
unique_labels = set(df['label'])
df_labels = pd.DataFrame( columns=['label', 'n_most_freq_words', 'n_most_freq_words_frequencies'])
for label in unique_labels:
    words_freq = labels_most_frequent_words(df, label=label, column='lemmas', n_words = 100, visualise = False)
    words = [word for word, freq in words_freq]
    df_labels = df_labels.append({'label': label, 'n_most_freq_words':words,'n_most_freq_words_frequencies':words_freq}, ignore_index=True)
df_labels
# Out:
#             label                                  n_most_freq_words  \
# 0            slur  [cunt, fucking, fuck, idiot, shit, dumb, lol, ...
# 1         hostile  [people, woman, black, like, white, fucking, l...
# 2          racist  [islam, muslim, mohammed, religion, isi, jew, ...
# 3      homophobic  [fucking, fuck, child, faggot, shit, nigger, h...
# 4   cyberbullying  [bitch, fake, like, get, fucking, shit, know, ...
# 5         obscene  [fuck, suck, shit, fucking, as, nigger, bitch,...
# 6          threat  [die, as, kill, going, block, fuck, must, jim,...
# 7   identity_hate  [nigger, jew, fat, gay, fuck, die, faggot, fuc...
# 8         hateful  [bitch, faggot, like, trumpisatraitor, nigga, ...
# 9      harassment  [jew, fucking, whitegenocide, white, muslim, c...
# 10      offensive  [bitch, hoe, like, pussy, nigga, as, got, fuck...
# 11         sexist  [sexist, mkr, woman, girl, kat, female, like, ...
# 12   severe_toxic  [fuck, suck, as, shit, faggot, bitch, fucking,...
# 13         vulgar  [shit, hell, damn, fuck, as, bitch, like, fuck...
# 14         insult  [fuck, suck, nigger, fucking, faggot, as, bitc...
# 15          abuse  [fuck, fucking, child, shit, mod, hillary, cli...
# 16        profane  [fucktrump, fuck, dickhead, trump, fucking, do...
#
#                         n_most_freq_words_frequencies
# 0   [(cunt, 5722), (fucking, 2148), (fuck, 2103), ...
# 1   [(people, 567), (woman, 540), (black, 382), (l...
# 2   [(islam, 645), (muslim, 598), (mohammed, 202),...
# 3   [(fucking, 3346), (fuck, 2802), (child, 1321),...
# 4   [(bitch, 112), (fake, 107), (like, 72), (get, ...
# 5   [(fuck, 9921), (suck, 4089), (shit, 3225), (fu...
# 6   [(die, 1168), (as, 772), (kill, 505), (going, ...
# 7   [(nigger, 3088), (jew, 1499), (fat, 1322), (ga...
# 8   [(bitch, 270), (faggot, 253), (like, 246), (tr...
# 9   [(jew, 2581), (fucking, 712), (whitegenocide, ...
# 10  [(bitch, 11195), (hoe, 4212), (like, 2378), (p...
# 11  [(sexist, 950), (mkr, 852), (woman, 686), (gir...
# 12  [(fuck, 7319), (suck, 3496), (as, 2115), (shit...
# 13  [(shit, 1126), (hell, 1033), (damn, 897), (fuc...
# 14  [(fuck, 7976), (suck, 3746), (nigger, 2890), (...
# 15  [(fuck, 2889), (fucking, 2694), (child, 1317),...
# 16  [(fucktrump, 315), (fuck, 133), (dickhead, 110...

# %% [markdown]
# ### tf-idf, word2vec, glove, fasttext

# %%
import gensim
import gensim.downloader
from gensim.models.fasttext import load_facebook_vectors

# %%
model_gn_glove = gensim.downloader.load('glove-wiki-gigaword-300')
model_gn_word2vec = gensim.downloader.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 376.1/376.1MB downloaded

# %%
df_labels[df_labels['label']=='vulgar']['n_most_freq_words'].iloc[0][0]
# Out:
# 'shit'

# %%
def get_word_embeddings(labels, df, list_of_words_column, model_gn, top_n):
    word_clusters = []
    embedding_clusters = []
    model_unknown_words = []
    for label in labels:
        label_words = df[df['label']==label][list_of_words_column].iloc[0]
        embeddings = []
        words = []
        for word in label_words:
            try:
                embeddings.append(model_gn[word])
                words.append(word)
            except KeyError:
                #print(word)
                model_unknown_words.append(word)
                pass
            
        words = words[:top_n]
        embeddings = embeddings[:top_n]

        embedding_clusters.append(embeddings)
        word_clusters.append(words)
    print(model_unknown_words)
    return word_clusters, embedding_clusters

def displayDF(word_clusters, labels):
    df = pd.DataFrame(dict(zip(labels, word_clusters)))  
    display(df)
    
def plot_similar_words(title, labels, embedding_clusters, word_clusters, filename=None):
    # function code taken from labs
    plt.figure(figsize=(16, 9))
    colors = cm.rainbow(np.linspace(0, 1, len(labels)))
    for label, embeddings, words, color in zip(labels, embedding_clusters, word_clusters, colors):
        x = embeddings[:, 0]
        y = embeddings[:, 1]
        plt.scatter(x, y, color=color, alpha=0.7, label=label)
        for i, word in enumerate(words):              
            plt.annotate(word, alpha=0.5, xy=(x[i], y[i]), xytext=(5, 2),
                         textcoords='offset points', ha='right', va='bottom', size=8)
        plt.annotate(label.upper(), alpha=1.0, xy=(np.mean(x), np.mean(y)), xytext=(0, 0),
            textcoords='offset points', ha='center', va='center', size=15)
    plt.legend(loc=4)
    plt.title(title)
    plt.grid(False)
    if filename:
        plt.savefig(filename, format='png', dpi=150, bbox_inches='tight')
    plt.show()
    
def plotTSNE(title, labels, word_clusters, embedding_clusters, filename = None):
    # function code adapted from labs
    embedding_clusters = np.array(embedding_clusters)
    n, m, k = embedding_clusters.shape
    model_en_2d = TSNE(perplexity=15, n_components=2, init='pca', n_iter=3500, random_state=32)
    model_en_2d = model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))
    embeddings_en_2d = np.array(model_en_2d).reshape(n, m, 2)
    plot_similar_words(title, labels, embeddings_en_2d, word_clusters, filename)
    
def plotMDS(title, labels, word_clusters, embedding_clusters, filename = None):
    # function code adapted from labs
    embedding_clusters = np.array(embedding_clusters)
    n, m, k = embedding_clusters.shape
    model_en_2d = MDS(n_components=2, max_iter=3500, random_state=32)
    model_en_2d = model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))
    embeddings_en_2d = np.array(model_en_2d).reshape(n, m, 2)
    plot_similar_words(title, labels, embeddings_en_2d, word_clusters, filename)
    
def plotPCA(title, labels, word_clusters, embedding_clusters, filename = None):
    # function code adapted from labs
    embedding_clusters = np.array(embedding_clusters)
    n, m, k = embedding_clusters.shape
    model_en_2d = PCA(n_components=2, random_state = 32)
    model_en_2d = model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))
    embeddings_en_2d = np.array(model_en_2d).reshape(n, m, 2)
    plot_similar_words(title, labels, embeddings_en_2d, word_clusters, filename)

# %% [markdown]
# ### TF-IDF embeddings visualisations

# %%
tf_idf_corpus = [' '.join(sentence) for sentence in list(df['lemmas'])]
#tf_idf_corpus

# %%
k = 10
top_k_dict = {}
words_by_label_string = {}

for label in unique_labels:
    tmp = df[df['label'] == label]['lemmas']
    tmp = tmp.apply(pd.Series).stack().reset_index(drop=True)
    words_by_label_string[label] = ' '.join(list(tmp.values))
    tmp = tmp.value_counts(normalize=True)[:k]
    top_k_dict[label] = tmp

# %%
#words_by_label_string is a dictionary

# %%
top_n_words = 10

tfIdfVectorizer=TfidfVectorizer()
X_tf_idf_non_array = tfIdfVectorizer.fit_transform(list(words_by_label_string.values()))
X_tf_idf = X_tf_idf_non_array.toarray()
vocab = tfIdfVectorizer.vocabulary_
reverse_vocab = {v:k for k,v in vocab.items()}
feature_names = tfIdfVectorizer.get_feature_names()
df_tfidf = pd.DataFrame(X_tf_idf, columns = feature_names)
idx = X_tfidf.argsort(axis=1) #sort and get idx for sorted values
tfidf_max_n = idx[:,-top_n_words:] # select top n words from sorted indexes
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-296-d5796769bf1f> in <module>
#       8 feature_names = tfIdfVectorizer.get_feature_names()
#       9 df_tfidf = pd.DataFrame(X_tf_idf, columns = feature_names)
# ---> 10 idx = X_tfidf.argsort(axis=1) #sort and get idx for sorted values
#      11 tfidf_max_n = idx[:,-top_n_words:] # select top n words from sorted indexes
#      12
#
# MemoryError: Unable to allocate 11.0 GiB for an array with shape (11314, 130107) and data type int64

# %%
print(X_tfidf.shape)
tfidf_max_n.shape
# Out:
# (11314, 130107)
# (11314, 10)

# %%
tfidf_max_n = idx[:,-top_n_words:] # select top n words from sorted indexes
tfidf_max_n.shape
# Out:
# (11314, 10)

# %%
lst = [[reverse_vocab.get(item) for item in row] for row in tfidf_max_n]

# %%
lst
# Out:
# [[None, None, None, None, 'reddit', None, None, None, None, 'sesspool'],
#  ['coherent',
#   None,
#   None,
#   'shameonicc',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'stiletto'],
#  [None,
#   'nationaldayofprayer',
#   'bossd',
#   'wrxwnaeb',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'burnhamthorpe'],
#  [None,
#   None,
#   'trumpdistractons',
#   None,
#   None,
#   'morrow',
#   None,
#   'ltr',
#   None,
#   None],
#  [None, None, 'sake', None, None, None, None, 'repressive', None, None],
#  [None, None, None, 'shti', None, None, None, None, 'westbank', None],
#  ['vengeance',
#   None,
#   None,
#   'vuitton',
#   None,
#   'recreate',
#   'nwcu',
#   None,
#   None,
#   'puttin'],
#  [None,
#   None,
#   'groin',
#   None,
#   None,
#   None,
#   'socialjustice',
#   'bachchan',
#   'returnthefavor',
#   None],
#  [None, 'pwinfa', None, 'ziegler', None, None, None, None, 'reality', None],
#  [None,
#   None,
#   None,
#   None,
#   'victimizes',
#   'worsum',
#   None,
#   None,
#   'onit',
#   'qibnqu'],
#  ['burgler',
#   'drafting',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'tajiana',
#   'stratos',
#   None],
#  [None, None, None, None, None, 'snowy', None, None, None, None],
#  [None, None, None, 'sue', None, None, None, None, None, 'simulate'],
#  ['malik', None, None, None, None, 'sep', None, None, None, None],
#  ['murda',
#   None,
#   None,
#   'replying',
#   None,
#   'assimilated',
#   'malnutrition',
#   None,
#   None,
#   None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, None, None, None, 'symonds', None],
#  [None, None, None, None, None, 'islamo', 'sesspool', None, None, None],
#  [None, None, None, None, None, 'spine', 'mqwk', 'mramnesia', None, None],
#  [None, None, 'peodphile', None, None, 'lose', 'raffle', None, 'eddine', None],
#  [None, None, None, None, 'seanses', None, None, None, None, None],
#  [None, None, None, None, 'servant', None, None, None, None, 'serv'],
#  [None, 'murda', None, None, None, None, None, None, None, 'shemale'],
#  ['irs',
#   'zaaaammnn',
#   None,
#   'illionaire',
#   None,
#   None,
#   'misandry',
#   None,
#   None,
#   None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None,
#   None,
#   'questioniaskmyself',
#   None,
#   None,
#   None,
#   'theyello',
#   None,
#   None,
#   None],
#  [None,
#   'producing',
#   None,
#   None,
#   None,
#   'zeifman',
#   None,
#   'nks',
#   None,
#   'procreated'],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, 'dlewis', None, None, 'rgeo', None, None, None, 'suede', 'signup'],
#  [None, None, None, 'tnd', 'tmnz', 'sesspool', None, None, None, None],
#  ['southerncharm',
#   None,
#   None,
#   None,
#   None,
#   'stateddiscussion',
#   'unpardonable',
#   'managed',
#   None,
#   'makesmethink'],
#  ['scherer',
#   None,
#   'macdonalds',
#   'yourjobsucks',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['nickey',
#   'tunisi',
#   'marchagainstwhitegenocide',
#   'motorsports',
#   None,
#   None,
#   'notyourscapegoat',
#   'nickyh',
#   None,
#   None],
#  [None, 'boogiedownbronx', None, None, None, None, None, 'spicer', None, None],
#  ['snigbrook',
#   'smelled',
#   'yurr',
#   None,
#   'snatching',
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None,
#   None,
#   'wantt',
#   'pretzel',
#   None,
#   'consoled',
#   'nativelivesmatter',
#   None,
#   None,
#   None],
#  [None,
#   None,
#   None,
#   'steward',
#   'stairway',
#   None,
#   'morgida',
#   'stare',
#   None,
#   None],
#  [None, None, None, None, None, None, None, 'pleaser', 'vinnies', None],
#  ['stunna', None, None, None, 'ooo', None, 'onee', None, None, None],
#  [None, 'nks', None, None, 'pellegrini', None, None, None, None, 'rab'],
#  [None, 'serv', 'marketing', None, None, None, 'noindirect', None, None, None],
#  [None,
#   None,
#   None,
#   'lop',
#   'iffhg',
#   'external',
#   'stealiing',
#   'wikitard',
#   None,
#   None],
#  ['murda', None, None, None, None, None, None, None, None, 'reserve'],
#  ['torture', None, None, None, None, None, 'pgot', None, None, None],
#  [None,
#   None,
#   None,
#   None,
#   'musical',
#   'reject',
#   'boastful',
#   None,
#   'streaking',
#   'vean'],
#  [None, 'gamaliel', None, None, None, None, None, None, None, None],
#  ['headsyoulose',
#   None,
#   None,
#   'yoonea',
#   None,
#   None,
#   None,
#   None,
#   'trumpliesmatter',
#   None],
#  ['tehdonald',
#   None,
#   None,
#   None,
#   None,
#   'ecochamer',
#   'entail',
#   'factualof',
#   None,
#   None],
#  ['uoe', None, None, None, 'sendinh', None, None, None, 'bushwhacking', None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None,
#   'naaa',
#   'prelude',
#   'steamroll',
#   None,
#   'nerdishm',
#   None,
#   None,
#   'simplify',
#   None],
#  [None, None, None, None, None, None, None, 'sena', 'confidential', 'proove'],
#  ['marco', None, None, None, 'rfvbn', None, None, None, None, 'worker'],
#  ['nimbus',
#   None,
#   'canoe',
#   None,
#   None,
#   'murda',
#   None,
#   'suplexin',
#   None,
#   'noavail'],
#  [None, 'sfcl', None, 'firebase', None, 'straigh', None, None, 'trope', None],
#  [None, None, None, None, None, None, None, None, 'ons', None],
#  ['realfriends',
#   None,
#   None,
#   None,
#   None,
#   'whatifisay',
#   None,
#   'yeaaaaahhhh',
#   None,
#   'turbulence'],
#  [None, None, None, None, 'petty', None, None, None, None, None],
#  [None, None, None, 'obzs', None, None, 'sheared', None, None, None],
#  [None,
#   'unpredictable',
#   'scherer',
#   None,
#   None,
#   'true',
#   None,
#   'unpaid',
#   None,
#   'prude'],
#  [None, 'onpoli', None, None, None, None, None, None, 'pricing', None],
#  [None,
#   None,
#   None,
#   'doughnut',
#   None,
#   'usernames',
#   'show',
#   None,
#   'priestess',
#   None],
#  ['itsjustweird',
#   'regi',
#   None,
#   'stunned',
#   None,
#   None,
#   'menial',
#   'accurately',
#   'shrunken',
#   'nyo'],
#  ['wikidas',
#   'watchlikeaking',
#   None,
#   None,
#   None,
#   None,
#   'ontop',
#   None,
#   'obstructs',
#   None],
#  [None, None, 'looney', 'lightning', None, None, None, None, None, None],
#  ['tfd',
#   None,
#   None,
#   'illustrious',
#   'youresexist',
#   None,
#   'goback',
#   None,
#   None,
#   None],
#  ['tujhe', None, None, None, None, None, 'pto', 'true', None, 'objectivist'],
#  [None, None, None, None, 'qquit', None, 'psst', None, None, None],
#  [None,
#   None,
#   'kill',
#   'espabangalore',
#   'droid',
#   'pbr',
#   None,
#   'verb',
#   None,
#   None],
#  [None, None, None, None, 'noavail', None, 'murda', None, 'noamnesty', None],
#  [None, None, None, None, None, None, None, None, None, 'scvkloa'],
#  ['seeit',
#   None,
#   'theowlandthekey',
#   None,
#   None,
#   None,
#   None,
#   'bahaullah',
#   None,
#   'pgqsy'],
#  [None,
#   None,
#   'supervisor',
#   'quita',
#   None,
#   None,
#   'venezuela',
#   None,
#   'oppositionthat',
#   None],
#  [None,
#   None,
#   'git',
#   'hajr',
#   None,
#   None,
#   'mygirlfriendnotallowedto',
#   'niggaaaaa',
#   'welcometothedollhouse',
#   'proselytist'],
#  ['qibnqu',
#   None,
#   None,
#   None,
#   'witts',
#   'peoepel',
#   'thinkreadact',
#   None,
#   None,
#   None],
#  ['wikiprostitute', 'maam', None, None, None, None, None, None, None, None],
#  [None, None, 'cater', None, None, None, 'seent', 'totaal', None, 'mandate'],
#  [None,
#   None,
#   'shortage',
#   'teri',
#   None,
#   None,
#   None,
#   None,
#   'pucture',
#   'reinvent'],
#  [None, None, None, None, None, None, None, 'prisoner', 'realism', 'realizng'],
#  [None, 'racialark', 'needlessly', None, None, None, None, None, None, None],
#  [None, 'tdlr', None, 'sombady', None, 'pot', None, None, None, 'secularism'],
#  [None,
#   None,
#   None,
#   'mackcan',
#   'mason',
#   None,
#   'newyorkgirlsbelike',
#   'tattooing',
#   'trumphastinyhands',
#   'wierd'],
#  [None, None, 'fish', None, 'estimation', None, 'sup', None, 'ammended', None],
#  ['verb', 'pbcf', None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, None, None, None, 'schooler', None],
#  [None,
#   None,
#   None,
#   'recipient',
#   None,
#   None,
#   'richly',
#   'phucking',
#   'trumpy',
#   None],
#  [None, None, 'pjqwo', None, None, None, 'lsjqtay', None, None, None],
#  [None, None, None, None, None, None, None, 'malnutrition', 'replying', None],
#  [None,
#   None,
#   None,
#   'subvert',
#   None,
#   'nstraight',
#   'sworn',
#   None,
#   None,
#   'hypocrisy'],
#  [None, None, None, None, None, None, None, None, 'obesity', 'datbr'],
#  [None, None, 'murda', 'nimbus', None, None, None, 'suchh', 'normandy', None],
#  [None, None, 'thegodgames', None, None, 'uhhm', None, None, 'splurge', None],
#  ['totheov', None, None, None, 'fdoc', None, None, None, None, None],
#  [None, None, 'hatered', 'brando', None, None, None, 'toughguy', None, None],
#  [None,
#   'randi',
#   'kindergartner',
#   None,
#   'studying',
#   'stuff',
#   'illegalimmigrants',
#   'youa',
#   'suicidal',
#   'truthiness'],
#  ['thst', None, None, None, 'sike', 'waltz', None, None, None, None],
#  ['waggers',
#   None,
#   'scully',
#   'scumbag',
#   'twudai',
#   'priiiiiiiiiiiick',
#   None,
#   None,
#   None,
#   None],
#  [None,
#   None,
#   'squatting',
#   None,
#   'vermontproblems',
#   None,
#   None,
#   'manipulative',
#   'userboxes',
#   'playnine'],
#  ['makeshitup',
#   'theorist',
#   None,
#   'servile',
#   None,
#   'reffing',
#   None,
#   None,
#   None,
#   None],
#  [None, None, None, None, None, None, None, None, 'stupidity', None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, 'wax', None, None, None, None],
#  [None, None, None, None, None, None, None, 'shmoke', None, None],
#  [None, None, 'stealiing', None, 'yolo', None, None, None, 'multimedia', None],
#  [None,
#   None,
#   None,
#   'overvaluing',
#   'wikitard',
#   None,
#   'sherlock',
#   None,
#   None,
#   None],
#  [None,
#   None,
#   'seperate',
#   None,
#   'nationalcheeseday',
#   None,
#   None,
#   None,
#   None,
#   'viet'],
#  [None, None, 'motivational', None, None, 'pogoed', None, None, None, 'pboc'],
#  ['dooche',
#   None,
#   None,
#   None,
#   'wilt',
#   'pulling',
#   'boston',
#   'obsession',
#   None,
#   None],
#  ['forgiverelease',
#   None,
#   None,
#   None,
#   'gameguide',
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['trumpisaliar',
#   None,
#   'unscrew',
#   'norse',
#   None,
#   'starleasha',
#   None,
#   None,
#   None,
#   'toryleadership'],
#  ['tec',
#   'sucket',
#   'theowlandthekey',
#   'malec',
#   None,
#   'turbo',
#   'urba',
#   'shot',
#   None,
#   None],
#  ['manning',
#   None,
#   'ev',
#   'verb',
#   None,
#   'ambiguous',
#   'thegodgames',
#   None,
#   None,
#   'edouard'],
#  [None, None, None, None, None, None, None, 'rebelious', None, None],
#  [None,
#   None,
#   'yuuge',
#   'trumpisaliar',
#   'bastilleday',
#   None,
#   'salvador',
#   'unscrew',
#   None,
#   None],
#  [None,
#   None,
#   'removethefakeassrepublicans',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None, None, None, None, None, None, 'nutbag', None, None, None],
#  ['mutherfucking',
#   'thrusting',
#   'steward',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'morgida',
#   None],
#  [None, None, None, None, 'lzmrlpyuep', None, 'summ', None, None, None],
#  [None, 'samaria', 'pumping', None, None, None, None, None, None, 'youknowme'],
#  ['practicing', None, None, None, None, None, None, 'soooooooo', None, None],
#  [None,
#   None,
#   'penetration',
#   'pretzel',
#   None,
#   None,
#   'tipping',
#   None,
#   None,
#   None],
#  [None,
#   None,
#   'dissapointment',
#   'hannity',
#   None,
#   None,
#   'upppp',
#   None,
#   None,
#   None],
#  [None, 'nyrblog', 'wiitard', None, None, 'yoir', None, None, None, None],
#  ['soooooooo',
#   'relating',
#   None,
#   None,
#   'wiitard',
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None, None, None, None, None, None, 'killong', None, None, 'estimating'],
#  [None, None, None, None, None, None, 'shotty', None, None, None],
#  ['parlay',
#   'stun',
#   None,
#   None,
#   'traphouseeeeeeee',
#   None,
#   'unsurprisingly',
#   None,
#   None,
#   None],
#  [None,
#   None,
#   'yataghan',
#   'reduce',
#   None,
#   'mamapopelives',
#   None,
#   'secretly',
#   None,
#   'rdtm'],
#  [None, None, 'prevalent', 'repressive', None, None, None, None, None, None],
#  ['youngiest', 'sheaa', None, None, None, None, None, None, 'mouthful', None],
#  [None,
#   None,
#   None,
#   'suburban',
#   None,
#   'shameonicc',
#   None,
#   None,
#   'whiteghazi',
#   None],
#  ['buhay',
#   None,
#   None,
#   None,
#   None,
#   'worthlessness',
#   None,
#   None,
#   'paresh',
#   'vadalizm'],
#  ['snutty',
#   None,
#   None,
#   None,
#   None,
#   'murda',
#   None,
#   'meganam',
#   'noamnesty',
#   None],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   'movses',
#   None,
#   'wheredidmychildhoodgo',
#   None,
#   None],
#  ['recreate',
#   'hatredisincreasing',
#   'moglucy',
#   None,
#   None,
#   None,
#   None,
#   'tove',
#   None,
#   None],
#  [None, None, None, None, None, None, None, None, None, None],
#  ['sewing', None, 'dizzy', None, None, None, None, None, 'mako', None],
#  [None,
#   None,
#   'maoist',
#   None,
#   None,
#   None,
#   None,
#   'trumpdistractons',
#   'dere',
#   None],
#  [None, None, 'wtyi', None, 'sooooon', None, None, 'tapout', None, None],
#  [None, 'optic', None, None, None, None, 'smosh', None, None, 'mussies'],
#  [None,
#   None,
#   None,
#   'obstructionofjustice',
#   'amdin',
#   'spent',
#   None,
#   None,
#   'buttcoin',
#   'dopauuphpq'],
#  ['gaya',
#   'speedy',
#   'ezidis',
#   None,
#   'sneakersex',
#   None,
#   None,
#   'dairy',
#   'showtime',
#   None],
#  [None,
#   'prevarication',
#   None,
#   None,
#   None,
#   'crown',
#   'accomplice',
#   None,
#   None,
#   None],
#  ['discourtesy',
#   'drenched',
#   'detachment',
#   'changan',
#   'blackandwhite',
#   'painlessly',
#   'guzzling',
#   'lmaoooooo',
#   None,
#   'ose'],
#  ['moreloud', None, None, None, None, None, 'yogurt', None, None, None],
#  [None,
#   None,
#   'dlisted',
#   None,
#   None,
#   None,
#   'expendable',
#   'diya',
#   None,
#   'barricade'],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None,
#   None,
#   'vpxxyhqaqd',
#   None,
#   'bitchesbelike',
#   None,
#   None,
#   None,
#   'needy',
#   'needtobuyticketsnow'],
#  [None, 'husband', 'sango', None, None, None, None, None, None, None],
#  ['heil',
#   'islamicstate',
#   'wikepedia',
#   None,
#   'gazaunderattack',
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None,
#   None,
#   None,
#   'rayrice',
#   'shouldnthave',
#   'timberly',
#   'uninvited',
#   'realnigga',
#   None,
#   None],
#  [None, None, None, None, None, None, 'motorsports', None, None, None],
#  [None, None, None, None, None, 'offensively', None, None, None, None],
#  [None,
#   None,
#   None,
#   'ynnvffsroa',
#   None,
#   'minortiy',
#   None,
#   None,
#   None,
#   'tonydonald'],
#  ['epoynme',
#   None,
#   None,
#   'weighs',
#   None,
#   'nenakelly',
#   None,
#   None,
#   None,
#   'realism'],
#  ['peruvian',
#   None,
#   None,
#   'tiddy',
#   None,
#   'standupforeurope',
#   'madarchod',
#   None,
#   'sesspool',
#   None],
#  [None, None, None, None, None, None, None, None, None, 'superdelegates'],
#  ['washed', None, 'suks', None, None, None, None, None, None, 'twitpic'],
#  [None,
#   'refering',
#   None,
#   'soooo',
#   'ogelizabeth',
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None, None, 'nustice', 'xtian', None, None, None, None, None, None],
#  ['reeeeeaaally',
#   'totallynotrobots',
#   'suicidal',
#   None,
#   None,
#   None,
#   None,
#   'veggie',
#   'vehicle',
#   'franca'],
#  [None, None, None, 'renamed', None, 'weirdness', None, 'spewer', None, None],
#  [None, None, None, None, 'preity', None, None, None, 'kil', 'kik'],
#  [None,
#   'mama',
#   None,
#   None,
#   'mmmmmmmmmmmmmmm',
#   'squeal',
#   'rajdeep',
#   'tryout',
#   None,
#   None],
#  ['shahnama',
#   'pigdogs',
#   None,
#   'thieving',
#   None,
#   None,
#   None,
#   'qrismx',
#   'refernxce',
#   'quebecois'],
#  ['shocker',
#   None,
#   None,
#   None,
#   'reset',
#   None,
#   None,
#   'psychologically',
#   None,
#   'pay'],
#  [None, None, None, None, None, None, None, None, None, None],
#  ['scuddles', None, None, None, None, None, None, None, None, None],
#  [None,
#   'wikiterrorist',
#   None,
#   'unofficial',
#   None,
#   None,
#   'streamable',
#   'strait',
#   None,
#   'employing'],
#  [None,
#   None,
#   'starleasha',
#   None,
#   None,
#   None,
#   'preemptive',
#   None,
#   None,
#   'toryleadership'],
#  [None, 'banislam', None, None, None, None, 'twitpic', None, None, None],
#  [None,
#   None,
#   None,
#   'wheaties',
#   None,
#   'windmill',
#   None,
#   'sugioh',
#   'sidechick',
#   'upholding'],
#  [None, None, 'souray', None, None, 'innat', None, None, None, None],
#  [None,
#   'smokindrankin',
#   None,
#   'musical',
#   None,
#   None,
#   None,
#   'streaking',
#   None,
#   None],
#  [None,
#   None,
#   None,
#   'backpedals',
#   'qnvxhxgjim',
#   'relieved',
#   'qpc',
#   None,
#   None,
#   None],
#  ['weddingplanning',
#   None,
#   'somethingigetalot',
#   None,
#   'urbonics',
#   'railway',
#   None,
#   None,
#   None,
#   None],
#  ['ageold', 'summ', None, None, None, None, 'pelase', None, None, None],
#  ['niggaaaaa',
#   'stinginess',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'welcometothedollhouse'],
#  ['unpc',
#   None,
#   None,
#   None,
#   'onhere',
#   None,
#   None,
#   'rear',
#   'psychobitch',
#   'oppose'],
#  [None, None, 'sorrow', None, None, 'suicidal', None, None, None, None],
#  [None,
#   'ctcomics',
#   None,
#   'offbeat',
#   'pointa',
#   'shameless',
#   None,
#   None,
#   None,
#   None],
#  [None,
#   'summerreddit',
#   None,
#   'wikidicks',
#   'simpler',
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   'realdealbillmcneal',
#   None,
#   None,
#   'realer',
#   None],
#  [None, None, None, None, None, None, 'nsw', None, None, None],
#  ['thegodgames', None, None, 'schulz', None, None, None, None, None, None],
#  [None,
#   'blackfeminists',
#   'constantzeanu',
#   None,
#   'peddle',
#   None,
#   None,
#   None,
#   None,
#   'maule'],
#  [None, 'sent', None, None, None, None, None, None, None, None],
#  [None, 'deeside', None, None, None, None, 'iono', None, None, None],
#  [None,
#   None,
#   None,
#   'pharmacognosy',
#   None,
#   'nenakelly',
#   None,
#   None,
#   None,
#   None],
#  [None, None, 'summerreddit', 'ocra', 'gayer', None, None, None, None, None],
#  ['kindergarten', None, None, 'curving', None, None, None, None, None, 'yrn'],
#  ['tampico',
#   None,
#   'prime',
#   'sure',
#   'natsukawa',
#   'weaselheadedfucknugget',
#   'unstable',
#   'prominently',
#   'behavuour',
#   None],
#  ['queenveronica',
#   'morontario',
#   'wacthh',
#   None,
#   'pta',
#   'postin',
#   None,
#   None,
#   None,
#   'pop'],
#  [None,
#   'mediocre',
#   None,
#   None,
#   'totesmessenger',
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None, None, None, 'skimp', 'zaaaammnn', None, None, None, None, None],
#  ['steezemuffin',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'spilt',
#   None,
#   None,
#   'ohsnapyougotserved'],
#  [None, None, 'tove', None, None, None, None, None, None, 'wayofthebern'],
#  [None, None, None, None, None, 'shti', None, 'westbank', None, None],
#  [None, None, None, None, None, 'vgxgaqsuxc', None, 'purged', None, None],
#  [None, None, None, None, None, None, None, None, None, None],
#  ['volleyball',
#   None,
#   None,
#   'gabe',
#   None,
#   'pussiieee',
#   None,
#   'coomie',
#   'backlash',
#   'backpack'],
#  ['strike',
#   None,
#   'escorted',
#   None,
#   'rimz',
#   None,
#   'true',
#   None,
#   'streaking',
#   'stache'],
#  ['tiffanycarter', None, None, None, None, None, None, None, None, None],
#  ['ocra',
#   'wetback',
#   'kommandohimmler',
#   None,
#   'qnvxhxgjim',
#   None,
#   'somalia',
#   'mlg',
#   None,
#   None],
#  ['twerp', None, 'seal', None, 'kill', None, None, 'kik', 'kil', 'parable'],
#  [None,
#   'misha',
#   None,
#   None,
#   None,
#   'schulz',
#   'repopulating',
#   'worstpresidentever',
#   None,
#   None],
#  [None, 'inapropriote', 'verb', None, None, None, None, None, None, 'lostb'],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, None, 'lyra', None, None, None, None, None, None, None],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   'pocohontas',
#   'poccets',
#   None,
#   None,
#   'poccadishonest'],
#  [None,
#   None,
#   None,
#   'magnuming',
#   None,
#   None,
#   'mysterious',
#   None,
#   None,
#   'simultanea'],
#  [None, None, None, 'mothafuka', None, 'thefarix', None, None, None, None],
#  ['womenrights',
#   None,
#   'meccan',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'trumphasamicropeen'],
#  ['newl',
#   None,
#   'project',
#   'wbc',
#   None,
#   'cuntofahead',
#   None,
#   'lyntoncrosby',
#   None,
#   None],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'tickettttttttttttttttt',
#   'myn',
#   None,
#   None],
#  ['hickies', None, 'historyof', None, None, 'coomie', None, None, None, None],
#  [None, None, None, None, None, None, 'makerr', None, None, 'nenakelly'],
#  [None,
#   None,
#   'smutosaurus',
#   'photoset',
#   None,
#   'pointa',
#   'maintainer',
#   None,
#   'motoroboated',
#   None],
#  [None, 'motherf', None, None, None, 'raccoon', 'race', None, None, None],
#  ['shocker',
#   'whitewashed',
#   'museumofreddit',
#   'motivate',
#   'shovel',
#   None,
#   None,
#   'nikkiandkatie',
#   'skimp',
#   None],
#  [None, 'norse', None, None, None, None, 'pucture', None, None, None],
#  ['tweetsomethingyougetalot',
#   'fagex',
#   'willingness',
#   'muggy',
#   'alqaida',
#   None,
#   'knowledge',
#   None,
#   None,
#   None],
#  ['gayviolence',
#   'fermented',
#   'lpd',
#   'tweetsomethingyougetalot',
#   'fagex',
#   'willingness',
#   'alqaida',
#   'prickard',
#   'mightily',
#   None],
#  [None,
#   None,
#   'vatican',
#   None,
#   None,
#   'alientravellers',
#   None,
#   'hasta',
#   None,
#   None],
#  ['moghal',
#   'shamed',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'periodical',
#   'talent',
#   None],
#  ['unsubscribing',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'tiktok',
#   None,
#   'whitelivesmatt'],
#  ['sheet', None, 'puzzy', None, None, None, None, 'qdrdy', None, 'whitepride'],
#  ['aaa', None, None, None, 'sharts', 'odeh', None, 'vitamin', None, None],
#  [None, None, 'tortilla', 'scorn', None, None, None, None, 'predefine', None],
#  ['pricing',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'mongorrrrrians',
#   'stareing',
#   None,
#   None],
#  ['zaaaammnn', None, None, None, 'misandry', None, 'shoo', None, None, None],
#  [None, 'lwn', None, None, None, None, None, 'olj', None, 'mirrored'],
#  ['niiiieeegggaaa', None, 'mall', None, None, None, None, 'yer', None, None],
#  ['rousey',
#   None,
#   'explain',
#   None,
#   None,
#   None,
#   'pasha',
#   None,
#   'voluntarios',
#   None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, 'droids', 'bulbasuar', 'bebe', 'slot', None, None, None],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   'seal',
#   'sunny',
#   None,
#   'signedtothestreets',
#   None],
#  [None, 'poeple', None, 'splurge', 'usurped', None, None, None, None, None],
#  ['significantly',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'relating',
#   'curley',
#   None,
#   None],
#  [None, None, None, None, None, 'sloking', None, None, None, 'washingtonpost'],
#  ['standard',
#   'tricking',
#   'durita',
#   'seanses',
#   'shiii',
#   None,
#   'southampton',
#   None,
#   None,
#   None],
#  ['kingman',
#   'kingwalt',
#   None,
#   None,
#   None,
#   'wlc',
#   None,
#   'bigotry',
#   'nitwit',
#   None],
#  [None,
#   None,
#   None,
#   'simeone',
#   None,
#   None,
#   'gaumutra',
#   'yourselfr',
#   'smutted',
#   'uncensored'],
#  [None, None, None, 'whereby', None, None, None, None, 'nupsw', None],
#  [None, None, None, None, 'trope', None, None, 'smarter', None, 'titan'],
#  [None, 'foal', 'snowy', None, 'toch', None, None, None, 'rabindranath', None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, 'murda', None, None, None, None, None, None],
#  [None, None, None, None, None, None, 'geeen', None, None, None],
#  [None, None, None, 'maoist', 'musa', None, None, None, None, None],
#  ['pelase', None, None, None, None, None, None, None, None, 'nmjt'],
#  ['clean', None, None, None, None, None, 'politics', None, None, None],
#  ['spectactular',
#   'mouthy',
#   None,
#   None,
#   None,
#   'stuipd',
#   None,
#   None,
#   None,
#   None],
#  [None, 'divorcing', None, None, 'shti', None, None, 'vandalyse', None, None],
#  ['onlife', None, None, 'yessssirrrrr', None, None, None, None, None, None],
#  [None,
#   None,
#   'park',
#   'popularity',
#   None,
#   None,
#   None,
#   'reconsider',
#   None,
#   None],
#  ['reduction',
#   'ramon',
#   None,
#   None,
#   None,
#   None,
#   'wikiprostitute',
#   'maam',
#   None,
#   None],
#  [None, 'rear', None, None, None, 'sherrif', None, 'possum', None, None],
#  [None,
#   'sheltering',
#   None,
#   'thegodgames',
#   None,
#   'procreate',
#   None,
#   None,
#   'trumputin',
#   None],
#  [None, 'protein', None, None, None, None, None, None, 'meticulously', None],
#  [None,
#   'teamin',
#   'michiganmade',
#   None,
#   None,
#   None,
#   None,
#   'stereotypi',
#   None,
#   'personnel'],
#  [None,
#   'sesspool',
#   None,
#   'sts',
#   None,
#   None,
#   'sicsemperhumanus',
#   None,
#   None,
#   None],
#  [None,
#   None,
#   'streaking',
#   None,
#   'thiisss',
#   None,
#   None,
#   'mendacity',
#   None,
#   None],
#  ['mouthbreating',
#   'primaryday',
#   None,
#   None,
#   'lwn',
#   None,
#   None,
#   None,
#   'mirrored',
#   None],
#  [None, 'sucksfrozen', None, None, 'miner', None, None, None, None, None],
#  [None, None, None, None, None, None, None, None, None, None],
#  ['riggr', 'rdh', 'cathedral', 'timer', None, None, None, 'aaa', None, None],
#  [None, None, None, None, 'obtain', None, None, None, None, None],
#  [None,
#   None,
#   None,
#   'mensroom',
#   'peacexo',
#   'stern',
#   'siraan',
#   'whoami',
#   None,
#   None],
#  [None, None, None, None, None, None, None, None, 'sewing', None],
#  [None, None, None, None, None, 'txw', None, None, None, None],
#  [None, None, None, None, None, None, None, 'olg', None, None],
#  ['degenerating',
#   None,
#   'slew',
#   None,
#   'usurped',
#   None,
#   None,
#   'atthesamedamntime',
#   'realism',
#   'pooptweet'],
#  [None, None, None, 'cid', 'censure', None, None, None, 'turd', 'signup'],
#  [None, None, 'usurped', None, None, None, None, None, 'wine', None],
#  ['pop',
#   None,
#   'weaselheadedfucknugget',
#   'gamaliel',
#   'poked',
#   'ocra',
#   None,
#   'prominently',
#   None,
#   None],
#  [None, None, None, None, None, None, None, None, None, None],
#  ['naidu', None, None, None, None, None, 'staying', None, None, 'streaming'],
#  [None,
#   None,
#   'taaaiwaan',
#   None,
#   'donjr',
#   'newbiepedian',
#   'trope',
#   'newcastle',
#   None,
#   None],
#  [None, None, None, None, None, 'show', None, None, None, 'pop'],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, 'willed', None, None, 'whitel', 'michigander', None, None, None, None],
#  ['losty',
#   None,
#   'lostprophets',
#   'succ',
#   None,
#   'staunchly',
#   None,
#   'rapeyass',
#   None,
#   None],
#  [None, 'realnigger', None, None, None, None, None, None, None, None],
#  [None,
#   None,
#   'sfuyarhsp',
#   None,
#   'pgn',
#   None,
#   None,
#   None,
#   'looting',
#   'zjjzlwkcehu'],
#  ['define', None, 'suicidal', 'afambro', None, None, None, None, None, None],
#  [None,
#   None,
#   'musical',
#   None,
#   None,
#   None,
#   'rightwinglimbo',
#   None,
#   None,
#   'numeral'],
#  [None, None, None, None, None, None, None, None, None, 'nic'],
#  [None, None, None, None, 'dominion', None, None, None, 'weave', None],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'nerowhatever',
#   'tvc',
#   'suited',
#   'whore'],
#  [None, None, 'practicing', 'rapeugee', None, None, None, None, None, None],
#  [None, None, 'qdrdy', None, None, 'suddenly', None, None, 'wooooo', None],
#  ['invariably',
#   None,
#   'sclafani',
#   None,
#   None,
#   'murderous',
#   'sharpening',
#   None,
#   None,
#   'jclpfrs'],
#  [None,
#   None,
#   None,
#   'singling',
#   'ons',
#   None,
#   None,
#   'moongod',
#   'moustache',
#   None],
#  [None, None, None, None, None, None, None, None, None, None],
#  ['ctcher',
#   'consiter',
#   None,
#   'cary',
#   'bossing',
#   None,
#   None,
#   None,
#   None,
#   'yoooou'],
#  [None, None, None, 'prowling', 'pozzed', 'pedantic', None, None, None, None],
#  ['warn', None, None, None, None, None, None, 'mcgraw', None, None],
#  ['summ', None, None, None, 'tunisi', 'motorsports', None, None, None, None],
#  [None, 'scindia', None, None, None, None, None, None, None, None],
#  ['sulkowicz',
#   None,
#   None,
#   None,
#   'rabindranath',
#   None,
#   'medianarrative',
#   'nocontext',
#   'piqvnp',
#   None],
#  ['identify', None, 'spoked', None, None, None, None, None, 'thrifty', None],
#  [None,
#   'skyylevelmedia',
#   'southchicago',
#   'thirty',
#   None,
#   'timer',
#   None,
#   'southampton',
#   None,
#   'thirteen'],
#  [None, None, None, 'wikipeda', 'mall', None, None, None, None, None],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   'gluton',
#   'aiken',
#   None,
#   'alawis',
#   'mothafuggin'],
#  [None,
#   None,
#   'stronger',
#   None,
#   'womenrights',
#   'swooped',
#   None,
#   None,
#   None,
#   'trumphasamicropeen'],
#  [None, None, None, None, None, 'paxie', None, 'steer', None, None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, 'zeifman', None, None, None, None, None, None],
#  [None, 'qquit', None, None, 'txw', None, None, None, None, None],
#  ['rule', None, None, None, None, 'spotting', None, 'twicked', None, None],
#  ['trumpisaliar',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'exhibition',
#   None,
#   None,
#   'profited'],
#  [None, None, 'populated', None, None, None, None, None, None, None],
#  [None,
#   'peruvian',
#   None,
#   None,
#   'theprintopinion',
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None, None, None, None, 'seanses', None, None, None, None, None],
#  [None, None, 'igers', None, None, 'tpo', None, None, None, None],
#  [None,
#   None,
#   None,
#   'splurge',
#   'mlj',
#   'stealiing',
#   'skippy',
#   None,
#   'hanukkahsongs',
#   'betty'],
#  ['ammount',
#   'irregardless',
#   None,
#   None,
#   None,
#   'realism',
#   None,
#   None,
#   'philosophic',
#   'vanishing'],
#  ['obstructs',
#   'whitelivesmatt',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'kil',
#   None,
#   None],
#  [None, None, 'buhh', None, None, None, None, None, None, None],
#  [None, None, None, None, None, None, None, 'tjis', 'tambout', None],
#  [None, None, None, None, None, None, None, None, None, None],
#  ['writeing',
#   'yck',
#   None,
#   'promiss',
#   'lotrouble',
#   None,
#   'wdtprs',
#   None,
#   None,
#   None],
#  [None, 'wikitard', None, 'verb', None, None, None, 'sck', None, None],
#  [None,
#   None,
#   None,
#   None,
#   'secularism',
#   'murda',
#   None,
#   'tambout',
#   None,
#   'niggr'],
#  ['relgious',
#   None,
#   'ocra',
#   'shitheaded',
#   None,
#   'shitz',
#   None,
#   None,
#   None,
#   None],
#  [None, 'meghan', None, None, None, 'planing', None, None, None, 'tart'],
#  [None, None, None, None, None, 'ship', None, 'killong', None, None],
#  ['kik', None, None, 'marija', None, None, None, None, None, 'qxpu'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   'onscreen',
#   'subterfuge',
#   'smutosaurus',
#   None,
#   None],
#  [None, None, 'naw', 'zis', None, None, None, None, None, None],
#  ['shocker',
#   'realie',
#   'mother',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'summ',
#   'tunisi'],
#  ['copypasted', 'dekalb', None, None, None, None, None, None, None, None],
#  ['oswald',
#   'uganda',
#   'mobbed',
#   'stealiing',
#   None,
#   None,
#   None,
#   'lost',
#   'lyinggggg',
#   'accomplish'],
#  [None,
#   'luther',
#   None,
#   None,
#   None,
#   None,
#   'uughh',
#   None,
#   'trump',
#   'reinserting'],
#  ['bcz',
#   'calderdal',
#   'brainpower',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'pwinfa'],
#  ['thrifty', None, 'spoked', None, None, None, None, None, None, 'science'],
#  ['peaceout',
#   None,
#   None,
#   'lyfe',
#   'slovakia',
#   'musical',
#   None,
#   'lool',
#   'snowwywolf',
#   None],
#  [None, None, 'ironman', 'jockey', None, None, None, None, None, 'slot'],
#  ['heavily',
#   'regroup',
#   'purifier',
#   None,
#   'woooooo',
#   None,
#   'chuuu',
#   'registration',
#   None,
#   None],
#  [None,
#   None,
#   'wikiprostitute',
#   None,
#   'maam',
#   'tmm',
#   'shortened',
#   'sneeze',
#   None,
#   'recations'],
#  [None, None, None, None, None, 'nerf', 'wellyou', None, 'muhajirs', None],
#  [None, None, None, None, None, None, 'plasticassed', 'tights', None, None],
#  [None, 'preity', None, None, None, None, None, None, None, None],
#  [None, 'uughh', None, None, None, None, 'stopboris', None, None, None],
#  [None, 'summit', None, None, None, None, None, None, 'summertime', None],
#  [None, None, None, None, None, None, None, 'template', 'meteos', None],
#  [None, 'nok', None, None, None, None, 'doings', None, None, None],
#  [None, None, None, None, 'quasar', None, None, None, 'pop', None],
#  [None, None, None, None, 'mono', None, None, None, None, None],
#  [None, 'mamta', None, None, None, None, None, None, None, None],
#  [None,
#   None,
#   'suppporter',
#   'ohin',
#   'sinneed',
#   None,
#   None,
#   None,
#   'religioustoys',
#   'tpo'],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, None, None, None, None, 'soooooooo'],
#  ['pop', 'peabody', None, None, None, 'dumby', 'salvia', None, None, None],
#  [None, None, None, None, 'true', None, None, None, 'sulkowicz', None],
#  [None, None, None, 'danielholtzclaw', None, None, None, None, 'omar', None],
#  [None, None, None, None, 'porkninja', None, None, None, None, None],
#  ['toxin', None, None, 'pfh', 'putt', None, None, None, None, None],
#  [None, None, None, None, 'tailgating', None, None, None, None, None],
#  [None, None, 'murda', 'sterilize', None, None, None, None, None, None],
#  [None,
#   'cheated',
#   None,
#   'darren',
#   None,
#   None,
#   'parmo',
#   None,
#   None,
#   'thetoddshow'],
#  ['zombie', None, 'afaics', None, None, 'parable', None, None, None, None],
#  [None,
#   None,
#   None,
#   'eyelash',
#   'buying',
#   'manipulative',
#   'raccoon',
#   'race',
#   None,
#   None],
#  [None,
#   None,
#   'unpardonable',
#   None,
#   None,
#   None,
#   None,
#   'stateddiscussion',
#   None,
#   'makesmethink'],
#  [None, None, None, None, None, 'traded', None, None, None, None],
#  ['sure', None, 'slaved', None, None, None, None, None, None, None],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   'lyra',
#   'mazeltov',
#   'maybelline',
#   'reaesarch',
#   None],
#  [None, None, None, None, None, 'nodefense', None, 'pricing', 'weaver', None],
#  [None, None, None, None, None, None, 'medically', None, 'traitor', None],
#  [None, None, None, 'nmckgf', None, None, 'shaniqua', None, None, 'trueeee'],
#  [None,
#   None,
#   'ibos',
#   'notyourshield',
#   'pgwashere',
#   None,
#   None,
#   None,
#   'blocking',
#   'aa'],
#  [None, None, None, None, None, None, 'spill', 'lotr', None, None],
#  ['fireyourwriters',
#   None,
#   None,
#   'coolforthat',
#   None,
#   None,
#   'ianpugh',
#   None,
#   None,
#   None],
#  ['verrrrry', None, 'sunny', None, None, 'sewing', None, None, None, None],
#  ['bathroom',
#   None,
#   'backstabbing',
#   None,
#   None,
#   'upppp',
#   'twan',
#   'squander',
#   'vacarro',
#   'marudubshinki'],
#  [None, None, 'synth', 'murda', 'taquiyya', None, 'pluck', None, None, None],
#  ['murda', 'noamnesty', None, None, None, None, None, None, None, None],
#  ['manning',
#   None,
#   'thegodgames',
#   'lyingshs',
#   'crystalina',
#   None,
#   None,
#   None,
#   'poplular',
#   None],
#  [None,
#   'yeaimmaboss',
#   'sina',
#   None,
#   'luther',
#   None,
#   None,
#   None,
#   'timeout',
#   'uon'],
#  [None,
#   'starleasha',
#   None,
#   None,
#   'removethefakeassrepublicans',
#   'rena',
#   None,
#   None,
#   None,
#   'toryleadership'],
#  [None, 'pop', None, None, None, None, None, None, None, 'pished'],
#  [None, None, 'bright', None, None, None, None, 'unorganized', 'tasc', None],
#  ['vandalizim', None, None, None, None, 'swamp', 'utfuckin', None, None, None],
#  ['santin',
#   None,
#   None,
#   None,
#   'microscopicly',
#   None,
#   'met',
#   None,
#   None,
#   'threesome'],
#  ['filrting',
#   None,
#   None,
#   'smarter',
#   'wikitan',
#   'xfinity',
#   'wtc',
#   None,
#   'posterboi',
#   None],
#  [None, 'wiitard', None, None, None, None, None, 'veggie', None, 'obnoxious'],
#  ['nks',
#   'outing',
#   None,
#   None,
#   'followback',
#   'pretzel',
#   None,
#   None,
#   None,
#   'nowomenexis'],
#  ['hustlin',
#   'omnicron',
#   'islamicterrorism',
#   'womensrightsarehumanrights',
#   'crapped',
#   'isisaremuslims',
#   None,
#   None,
#   None,
#   None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, None, None, None, None, None],
#  ['whereas',
#   None,
#   'zobliviously',
#   None,
#   None,
#   'zeifman',
#   None,
#   None,
#   None,
#   None],
#  ['streaking',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'schooler',
#   None,
#   'winger',
#   'plolitics'],
#  [None, 'seaman', None, 'shocker', None, None, None, 'summ', None, 'tunisino'],
#  [None, 'tvc', None, None, 'remembered', 'virtuous', None, None, 'sgp', 'suh'],
#  [None,
#   'richhomiejuan',
#   'yousrself',
#   None,
#   None,
#   None,
#   None,
#   'mispeling',
#   None,
#   'waaaa'],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, 'mused', None, None, None, None, 'speedrunners', None, None, None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None,
#   'shoudnt',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'steward',
#   'muslimawarenessmonth',
#   None],
#  [None, None, 'patently', 'tmr', 'lotr', None, 'hammons', None, None, None],
#  [None,
#   'mkr',
#   'cunjuncture',
#   'striped',
#   None,
#   'utimate',
#   None,
#   None,
#   None,
#   None],
#  [None, 'pussyriot', None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, 'theyello', None, None, None, None],
#  ['rgeo',
#   None,
#   'matthew',
#   'verb',
#   None,
#   'ontop',
#   None,
#   'nastered',
#   None,
#   'peckerwood'],
#  [None,
#   'loot',
#   'scherer',
#   None,
#   None,
#   None,
#   'smmfh',
#   None,
#   'whatifisay',
#   None],
#  [None,
#   'dunno',
#   'luther',
#   'emokid',
#   'whitescantberaped',
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None, 'adina', None, 'ruinging', 'crusaded', None, None, 'stud', None, None],
#  [None, 'swrong', None, None, None, None, None, None, None, None],
#  ['vax', None, None, 'richeous', None, 'resented', None, None, None, None],
#  ['downvotes',
#   'crossed',
#   'drowners',
#   'wtc',
#   'ezidis',
#   None,
#   None,
#   None,
#   None,
#   'ringing'],
#  [None, None, None, None, 'stereotypi', None, 'markus', None, None, None],
#  [None, None, 'spine', 'racismvsblacks', None, None, None, None, None, None],
#  [None, 'sunnyslope', None, None, None, None, 'upset', None, None, None],
#  [None, None, None, None, 'redefine', 'quoth', 'kil', 'kill', 'signup', 'kik'],
#  ['unit',
#   'brettkavanaughrapist',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None,
#   'suh',
#   'tapdancing',
#   'shoutout',
#   None,
#   'profession',
#   None,
#   None,
#   None,
#   None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, 'suited', None, None, 'suker', None, None, None, None, 'twunt'],
#  [None,
#   None,
#   None,
#   'selfhate',
#   'miseducating',
#   'adviceforyoungfeminists',
#   None,
#   None,
#   None,
#   'uuuuggggggghhhhhhh'],
#  [None, None, 'rehabilitated', None, None, None, None, None, 'lukin', None],
#  [None, None, None, 'surrender', None, 'shiii', None, None, None, None],
#  [None, None, None, None, None, None, 'noyvous', None, 'broken', None],
#  ['moanin', None, None, None, None, None, 'wif', 'seanses', None, 'socail'],
#  [None, None, 'skimp', 'kill', 'kindle', None, None, 'sling', None, None],
#  ['promiss',
#   'lotrouble',
#   'milton',
#   'ioccfj',
#   'akkadian',
#   'gether',
#   'zeitgeist',
#   'survivorgamechangers',
#   None,
#   'zeifman'],
#  [None, None, 'pseudo', None, None, None, 'swastika', 'spilt', 'swat', None],
#  [None,
#   None,
#   'reppin',
#   'crossfire',
#   None,
#   'totesmessenger',
#   'medicare',
#   None,
#   None,
#   None],
#  [None, None, 'porkupine', 'mow', None, None, None, None, 'missile', 'missed'],
#  [None,
#   None,
#   'worstpresidentever',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'hannnnnn'],
#  ['shitlary',
#   None,
#   'streaking',
#   None,
#   None,
#   None,
#   None,
#   'zzzzzz',
#   'pgqsy',
#   None],
#  [None, None, 'murda', 'polock', None, 'meter', None, None, None, None],
#  ['varna', None, None, 'foal', None, None, None, None, 'rabindranath', None],
#  [None, None, None, None, 'whitelivesmatt', None, None, None, None, None],
#  [None,
#   'prom',
#   None,
#   None,
#   'miserably',
#   None,
#   None,
#   None,
#   'miscegenation',
#   None],
#  ['telaviv', None, None, None, None, None, 'veggie', 'needlessly', None, None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, 'thue', None, None, None, None, None, None],
#  [None, None, None, None, 'genre', 'angst', None, 'mused', None, None],
#  [None, None, None, None, None, 'overly', None, None, None, None],
#  [None,
#   None,
#   'malnutrition',
#   None,
#   None,
#   None,
#   'serval',
#   None,
#   'replying',
#   'serv'],
#  [None,
#   'slightest',
#   'seee',
#   None,
#   'protestman',
#   None,
#   None,
#   None,
#   None,
#   'mechanic'],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, 'thts', None, 'soon', None, 'rangzen'],
#  [None, None, 'trumpisaliar', None, None, None, None, None, None, None],
#  ['nooooooooo',
#   'perversion',
#   None,
#   None,
#   'studly',
#   None,
#   'pleaser',
#   'schooler',
#   None,
#   None],
#  [None, 'urchin', None, 'urbonics', None, None, None, None, None, None],
#  ['nobun', 'womb', None, 'warzone', None, 'letterman', None, None, None, None],
#  [None,
#   None,
#   None,
#   'climategate',
#   None,
#   'superseded',
#   None,
#   None,
#   'engineering',
#   'sadie'],
#  [None,
#   None,
#   None,
#   'relevant',
#   None,
#   'heedless',
#   None,
#   'erik',
#   'stiletto',
#   'ewwwwwww'],
#  [None, 'torture', None, 'sidechick', 'shouted', None, None, None, None, None],
#  [None,
#   None,
#   'twerp',
#   None,
#   'seal',
#   'stopwhitepeople',
#   None,
#   None,
#   None,
#   None],
#  [None, 'nustice', 'xtian', None, None, None, None, None, None, None],
#  [None, None, None, None, 'skimp', 'phqsq', None, None, None, 'shagger'],
#  [None,
#   None,
#   'trumpdistractons',
#   None,
#   None,
#   'trumped',
#   None,
#   None,
#   None,
#   None],
#  ['hardship',
#   None,
#   'fotoshop',
#   None,
#   None,
#   'perarl',
#   'smokereg',
#   None,
#   'trumpimpeachmentinquirynow',
#   None],
#  [None, 'steward', None, None, None, None, None, None, None, None],
#  ['muthaafuckin',
#   'whet',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'westbank',
#   None,
#   None],
#  ['warriorsvsspurs',
#   'blondie',
#   None,
#   'shouted',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'wagging'],
#  ['plein',
#   'shaky',
#   None,
#   None,
#   None,
#   'supergabbyshoe',
#   None,
#   None,
#   None,
#   None],
#  [None,
#   None,
#   'constantly',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'settlin',
#   'therapist'],
#  [None, None, None, None, 'onyur', None, None, None, None, None],
#  [None,
#   None,
#   'trumpdistractons',
#   'lonz',
#   None,
#   None,
#   None,
#   'trumped',
#   None,
#   None],
#  [None, None, None, 'musical', None, None, None, None, None, None],
#  [None,
#   'tweakin',
#   None,
#   None,
#   None,
#   'zanpakuto',
#   'wetter',
#   'poundshop',
#   None,
#   None],
#  [None, None, None, None, None, None, None, None, 'rewrote', None],
#  [None, None, None, None, None, None, None, 'slag', None, None],
#  ['veet',
#   'pucture',
#   'none',
#   'soooooooooo',
#   None,
#   None,
#   None,
#   None,
#   'theblairbetch',
#   None],
#  ['shylock',
#   'comix',
#   'pottyparity',
#   'raccoon',
#   None,
#   'race',
#   None,
#   'murked',
#   None,
#   None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, None, None, None, None, None],
#  ['aa', None, None, None, None, None, None, None, None, 'plot'],
#  [None, None, 'wlwqs', None, None, None, None, None, None, 'pressed'],
#  ['yyyyaaaaaayyyy', None, None, None, None, None, 'wahahah', None, None, None],
#  [None,
#   None,
#   'nickyh',
#   None,
#   None,
#   None,
#   'meschugener',
#   None,
#   None,
#   'manipulative'],
#  [None, 'misessus', None, 'tmuv', None, None, None, 'pubeless', None, None],
#  [None, None, None, 'pumping', None, None, None, None, None, None],
#  [None, 'pogoed', None, 'qdrdy', None, None, None, None, None, None],
#  ['wikepedia',
#   None,
#   'true',
#   None,
#   'gazaunderattack',
#   None,
#   'flip',
#   'adulthood',
#   None,
#   'walang'],
#  ['socail',
#   None,
#   'seanses',
#   None,
#   None,
#   'thickest',
#   None,
#   None,
#   'pledge',
#   None],
#  ['adjacent',
#   'astro',
#   'icon',
#   None,
#   None,
#   None,
#   None,
#   'pelase',
#   None,
#   'mound'],
#  [None, None, None, 'thanggg', None, 'relating', None, None, None, None],
#  [None,
#   None,
#   'wips',
#   None,
#   'qibnqu',
#   'thegodgames',
#   'dyslexia',
#   None,
#   None,
#   'reproduced'],
#  [None, None, None, None, None, None, None, None, None, None],
#  ['deicision', None, None, None, None, None, None, None, None, None],
#  ['wikipieida', None, None, None, None, 'utopiie', None, None, None, None],
#  ['nam', None, None, None, None, None, None, None, None, None],
#  ['ruthlessly', 'kahan', None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, 'meditation', None, None, 'niggur', None],
#  [None, None, None, None, 'queen', None, None, None, None, None],
#  ['mangina',
#   None,
#   None,
#   None,
#   'tang',
#   'nipping',
#   None,
#   None,
#   'nintendo',
#   None],
#  [None, 'repsonded', None, None, None, None, None, 'patai', None, None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, 'pricing', None, 'voicemail', None, None, None, None, None, None],
#  [None, None, None, None, None, None, 'looney', 'lightning', 'kqcx', None],
#  [None, None, None, None, 'youpedantic', None, None, 'rapdreams', None, 'tfm'],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None,
#   'patriarhy',
#   'hahahahhahahhahahahahahahahahahahahahahahahahahahahahahahaa',
#   'niteshift',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None,
#   'yolo',
#   'loot',
#   'misdeed',
#   None,
#   None,
#   None,
#   'seemingly',
#   'proposing',
#   'okie'],
#  [None, 'vsmith', 'trumpturd', None, None, 'taht', None, None, None, None],
#  [None,
#   None,
#   None,
#   'sensitivesaturday',
#   None,
#   None,
#   None,
#   None,
#   'westin',
#   None],
#  [None, 'murda', None, None, None, None, None, None, None, None],
#  [None,
#   'photoset',
#   'wikiprostitute',
#   None,
#   None,
#   None,
#   'maam',
#   'maintainer',
#   None,
#   'motoroboated'],
#  [None, None, None, 'psumark', 'paused', None, None, 'shti', 'pevert', None],
#  [None, 'mixon', None, None, None, None, None, 'ringgold', None, 'beggar'],
#  [None,
#   None,
#   'namesake',
#   'pottyparity',
#   None,
#   None,
#   None,
#   None,
#   'murked',
#   None],
#  [None,
#   'parallel',
#   'unsee',
#   'extremerules',
#   'rollins',
#   None,
#   'unscrew',
#   None,
#   'mangina',
#   None],
#  [None, None, 'rahman', None, None, None, None, None, None, None],
#  [None, 'sena', None, 'matilda', None, None, None, 'thetoddshow', None, None],
#  ['wikitard', None, None, None, None, None, None, None, None, None],
#  [None, None, None, 'upppp', 'fcukr', None, None, None, 'nenakelly', None],
#  [None, 'scherer', None, None, None, None, None, None, None, 'killalljews'],
#  [None, 'murda', 'pricing', None, None, None, None, None, None, None],
#  ['breakingnews',
#   None,
#   None,
#   'unsw',
#   None,
#   None,
#   None,
#   None,
#   'mamtafrustrated',
#   None],
#  ['uganda',
#   'brusselsattacks',
#   'georgina',
#   None,
#   None,
#   'belongs',
#   None,
#   None,
#   'bite',
#   'deem'],
#  [None, None, 'mvl', None, None, None, None, None, None, 'eduardo'],
#  ['exasperated', None, None, None, None, 'schooler', 'txw', None, None, None],
#  ['queermo',
#   None,
#   'uyghur',
#   None,
#   None,
#   None,
#   None,
#   'spookyblack',
#   'machiavelli',
#   'montenegrin'],
#  [None, None, None, 'resonance', None, None, 'dannyg', 'mouthful', None, None],
#  [None, 'ehvkxi', None, None, None, None, 'farrakhan', None, 'ehy', None],
#  [None,
#   None,
#   'schlh',
#   None,
#   None,
#   None,
#   None,
#   'subterfuge',
#   'pio',
#   'trenchant'],
#  [None,
#   None,
#   'sincethecubswonaworldseries',
#   None,
#   None,
#   'lud',
#   None,
#   None,
#   'lucricus',
#   None],
#  ['rightwinglimbo',
#   None,
#   'pgwashere',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'terrier',
#   None],
#  [None, None, None, None, None, None, 'worstpresidentever', None, None, None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, 'originally', None, 'omar', None, None, None, None, None, 'whoz'],
#  ['shrunken', 'slam', None, 'suntan', None, 'mfka', None, None, None, None],
#  ['stupidity', None, None, None, None, 'soooo', None, None, None, None],
#  ['sewing', None, None, 'vaa', None, None, None, None, 'railway', None],
#  [None,
#   None,
#   'ginobli',
#   None,
#   'reppin',
#   'whoz',
#   None,
#   None,
#   None,
#   'ventilator'],
#  [None, None, None, None, None, None, None, None, None, 'yeaboo'],
#  ['pridemonth', None, None, None, None, None, None, None, 'sena', None],
#  ['scherer', None, None, None, None, None, None, None, None, None],
#  ['sleepisfortheweak',
#   None,
#   'progresspics',
#   None,
#   'pricing',
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None,
#   None,
#   'resident',
#   None,
#   'magazine',
#   None,
#   None,
#   'multimedia',
#   None,
#   None],
#  ['michigander',
#   'rheumatism',
#   'streaking',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['scrubby',
#   'waynestated',
#   'trope',
#   'tattooing',
#   None,
#   None,
#   'wakeuplibs',
#   None,
#   None,
#   None],
#  [None, None, None, None, 'siziba', 'yougoglencoco', None, None, None, None],
#  ['jobbin',
#   'bowlvictory',
#   'silhouette',
#   'thrifty',
#   None,
#   'turnuuuuuh',
#   'recreate',
#   None,
#   'stavropolie',
#   None],
#  [None,
#   None,
#   'niccib',
#   None,
#   None,
#   None,
#   None,
#   'trumpisastupidcunt',
#   None,
#   None],
#  [None, 'vrati', None, None, None, None, None, None, None, None],
#  ['taj', None, None, None, 'rightfully', 'crr', None, None, None, None],
#  ['malo', None, 'ahh', None, None, None, None, None, 'datbr', None],
#  ['nxou',
#   None,
#   None,
#   None,
#   'selfiesonselfies',
#   'murda',
#   'nerdy',
#   None,
#   None,
#   'nwohoax'],
#  [None, None, None, None, None, None, None, 'spent', 'uughh', None],
# ...
#  [None, 'broken', None, None, None, None, None, None, None, None],
#  [None,
#   'islamic',
#   'show',
#   None,
#   None,
#   'poplular',
#   'shrunken',
#   'respectability',
#   None,
#   None],
#  [None, 'nebracka', None, None, 'sysop', 'yaaaas', None, None, None, None],
#  [None, 'suggested', None, None, None, None, None, None, None, None],
#  [None, 'nsister', None, None, None, None, None, None, 'stun', None],
#  ['murda', None, None, None, None, None, 'swagg', None, None, None],
#  [None, None, None, None, None, None, 'qdrdy', 'pwpxuwje', 'pgqsy', 'kil'],
#  ['hut', 'hegde', None, None, None, None, None, None, 'whistledick', None],
#  ['rapeugee',
#   None,
#   None,
#   None,
#   None,
#   'prom',
#   None,
#   None,
#   'uigowefm',
#   'receptive'],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'sheeeeeit',
#   'schooler',
#   'scokputter',
#   None],
#  [None,
#   None,
#   None,
#   'bragged',
#   'beleive',
#   None,
#   'marudubshinki',
#   'twan',
#   None,
#   None],
#  ['clicquot', None, None, None, 'memo', None, None, None, None, None],
#  [None,
#   'wikitard',
#   None,
#   None,
#   None,
#   None,
#   'somalian',
#   'stereotypi',
#   None,
#   None],
#  ['hatful', None, None, None, None, None, None, None, None, 'manipulative'],
#  [None,
#   'sesspool',
#   'splurge',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'targetted',
#   'notyourshield'],
#  [None,
#   None,
#   None,
#   'clown',
#   'grround',
#   'trumpdistractons',
#   None,
#   None,
#   None,
#   None],
#  [None, None, 'noavail', None, None, 'noamnesty', None, 'murda', None, None],
#  [None, None, 'nintendo', None, None, None, None, None, None, None],
#  [None, None, None, None, 'bender', None, 'durning', None, None, 'obup'],
#  [None, None, None, None, None, None, 'rapial', None, 'separatist', None],
#  [None, None, None, None, None, 'vent', 'ventilator', 'stupidity', None, None],
#  [None,
#   'gazaunderattack',
#   'trust',
#   'hapsburg',
#   'euv',
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None, 'midcarrage', None, None, None, None, None, None, None, None],
#  [None, 'mall', None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, None, None, None, 'makerr', None],
#  [None, None, None, 'whereupon', None, None, None, 'unused', None, None],
#  ['facial',
#   None,
#   'bottomline',
#   None,
#   'pepes',
#   None,
#   None,
#   None,
#   'progresspics',
#   'pasting'],
#  [None,
#   None,
#   'niggerperson',
#   None,
#   'restart',
#   'pewqh',
#   None,
#   None,
#   None,
#   None],
#  [None, None, None, None, None, None, None, 'mirrored', None, None],
#  ['thingsiliketodo',
#   None,
#   'scramblin',
#   None,
#   'deboer',
#   'cast',
#   None,
#   None,
#   'yoooooouuuu',
#   'uppity'],
#  [None,
#   'psychologist',
#   'morroco',
#   None,
#   None,
#   None,
#   None,
#   'peculiar',
#   None,
#   None],
#  [None,
#   None,
#   None,
#   'naidu',
#   'nooooooo',
#   None,
#   None,
#   'slovak',
#   None,
#   'slagging'],
#  [None,
#   'monthes',
#   None,
#   None,
#   'stopwhitepeople',
#   'prefrence',
#   None,
#   None,
#   None,
#   None],
#  [None, None, None, None, 'trumpisaliar', None, None, None, None, None],
#  [None,
#   'borderless',
#   'transmit',
#   None,
#   None,
#   None,
#   'shirtt',
#   'ramgarhia',
#   None,
#   None],
#  [None, 'preity', None, None, 'utivkgkuka', None, None, None, 'tiano', None],
#  [None,
#   'troubled',
#   None,
#   'trout',
#   'spicers',
#   'pint',
#   None,
#   'spicy',
#   'troll',
#   None],
#  ['trumpisanationaldisgrace',
#   None,
#   None,
#   None,
#   'going',
#   None,
#   None,
#   None,
#   'patrisio',
#   None],
#  ['suicidal',
#   None,
#   'shamed',
#   None,
#   None,
#   'cultish',
#   'defamed',
#   None,
#   'talent',
#   None],
#  [None, 'ibos', None, None, None, None, None, 'formspring', 'mistaken', None],
#  ['geggy', None, None, None, 'dam', None, 'replying', 'stard', 'pasha', None],
#  [None, 'norse', None, None, None, None, 'noamank', None, None, None],
#  ['fqmtqd',
#   'dwhxxriibj',
#   None,
#   'manzan',
#   None,
#   'fingernail',
#   None,
#   None,
#   'motivate',
#   None],
#  ['rungame', None, 'raccoon', None, 'race', None, 'mkr', None, 'rdh', None],
#  [None,
#   None,
#   'overstep',
#   None,
#   'wikiprostitute',
#   'citynews',
#   None,
#   None,
#   None,
#   None],
#  ['streaking',
#   None,
#   'fab',
#   'unaustralian',
#   'roni',
#   None,
#   'rakon',
#   None,
#   None,
#   None],
#  ['succeed', None, 'tommorow', None, None, None, None, None, 'teems', None],
#  ['misinterpret',
#   None,
#   'vandal',
#   'scherer',
#   None,
#   None,
#   'tangible',
#   None,
#   None,
#   None],
#  [None, None, None, None, None, 'weev', None, 'thegod', 'sexual', None],
#  ['boo',
#   'manuod',
#   'mixtapes',
#   None,
#   None,
#   'stallion',
#   None,
#   None,
#   None,
#   'socialjustice'],
#  [None, None, None, None, None, None, 'yay', None, None, None],
#  ['distonga',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'mazeltov',
#   'swap',
#   'maybelline',
#   None],
#  [None,
#   'tnxman',
#   'chojis',
#   'peeingmypants',
#   None,
#   None,
#   None,
#   None,
#   'pelase',
#   None],
#  ['lyfe', None, None, None, None, 'sucksfrozen', None, 'pillaged', None, None],
#  [None, None, None, None, None, 'theorist', None, None, 'misuse', None],
#  [None, 'rainsick', None, 'suh', 'seanses', None, None, None, None, None],
#  ['moneyroot',
#   'lyi',
#   None,
#   'gazelle',
#   None,
#   'true',
#   None,
#   None,
#   'sulkowicz',
#   None],
#  ['snippet', None, None, None, None, None, None, None, None, None],
#  [None,
#   None,
#   'nwohoax',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'marchagainstwhitegenocide',
#   'notyourscapegoat'],
#  [None,
#   'ohmygod',
#   None,
#   None,
#   None,
#   'predefine',
#   None,
#   'prowhite',
#   None,
#   None],
#  ['signup',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'oneletterofffoods'],
#  ['nickyh',
#   'spotty',
#   None,
#   None,
#   None,
#   'nickey',
#   'spouse',
#   None,
#   None,
#   'mosquito'],
#  [None,
#   'locktrumpup',
#   None,
#   'confident',
#   None,
#   None,
#   'truefaceofisrael',
#   None,
#   None,
#   None],
#  [None, None, None, None, 'thorough', None, None, None, None, None],
#  ['ciswhitemaelstrom',
#   None,
#   None,
#   'txw',
#   'bigoted',
#   'bending',
#   'throughout',
#   None,
#   'pacific',
#   None],
#  ['worthlessness',
#   'nontheist',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None, None, None, None, None, None, None, None, None, None],
#  ['meesrs', None, None, 'aa', None, None, None, None, None, None],
#  [None, 'sclafani', None, 'cuzzo', None, 'znation', None, None, None, None],
#  [None, 'watanabe', None, None, 'muhammy', None, 'shady', None, 'quake', None],
#  [None,
#   None,
#   None,
#   None,
#   'maam',
#   None,
#   None,
#   None,
#   'worstpresidentever',
#   None],
#  [None,
#   None,
#   'slowstir',
#   None,
#   'stereotypi',
#   None,
#   'steward',
#   None,
#   None,
#   None],
#  [None, None, None, None, None, None, None, None, 'poehler', None],
#  [None, None, 'niggaaaaaa', None, None, None, None, 'serously', None, None],
#  [None, None, 'steamroll', None, 'vandalizim', None, None, None, None, None],
#  ['nickey',
#   None,
#   None,
#   'nickyh',
#   None,
#   'noneeee',
#   None,
#   None,
#   'yuvrajsingh',
#   None],
#  ['cater', None, None, None, 'sequined', None, None, None, None, None],
#  [None, None, None, None, None, None, None, 'ultimatevictim', None, None],
#  ['stu', None, 'otay', None, None, None, None, None, None, None],
#  [None, None, 'nerf', None, 'randi', None, None, None, None, None],
#  ['helvetica', None, None, None, 'cater', None, None, None, None, None],
#  [None,
#   None,
#   'noavail',
#   None,
#   'murda',
#   'noamank',
#   'aaa',
#   None,
#   'noamnesty',
#   None],
#  [None, None, None, 'raccoon', 'race', None, None, None, None, None],
#  [None, None, 'shivam', None, None, None, None, None, 'relentlessly', None],
#  ['seanses', 'prudish', None, None, 'scorch', None, None, None, None, None],
#  ['beaver', 'ananth', 'lyra', None, 'true', None, None, None, None, None],
#  ['politicsmoderatorbot',
#   'weddingplanning',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'thebidenrule'],
#  ['pau', None, 'book', 'hamas', 'flaka', None, None, None, None, None],
#  [None, None, None, None, None, 'corinthian', None, None, 'protestman', None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None,
#   None,
#   'segregatetoday',
#   None,
#   'segregateforever',
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['fckn', None, None, None, None, None, None, 'namaz', None, None],
#  ['stronger',
#   'suicidal',
#   'dubass',
#   None,
#   'piqvnp',
#   'worthlessness',
#   None,
#   'wancker',
#   None,
#   'opulence'],
#  ['vviha', None, None, 'vvgq', None, 'robb', None, None, 'montage', None],
#  [None,
#   'welton',
#   'profitable',
#   'brasilians',
#   'court',
#   None,
#   None,
#   'malnutrition',
#   None,
#   'replying'],
#  ['ballot',
#   'igge',
#   None,
#   None,
#   None,
#   'questforpositivity',
#   'dolled',
#   'eqvbojw',
#   'questionyouwontheartomorrowbecauseitsirrelevant',
#   None],
#  [None, None, None, None, 'murda', None, None, None, None, None],
#  ['collusion',
#   None,
#   'trumpisaliar',
#   None,
#   None,
#   'pwnd',
#   None,
#   None,
#   None,
#   None],
#  [None, None, None, None, None, None, None, None, 'suckas', 'yourt'],
#  ['removethefakeassrepublicans',
#   'shalll',
#   'restau',
#   None,
#   'rdramas',
#   None,
#   None,
#   'patriarchal',
#   None,
#   None],
#  [None,
#   'dcpo',
#   'rugrats',
#   'omar',
#   'freeamosyee',
#   'obsession',
#   None,
#   None,
#   None,
#   None],
#  [None, 'amcon', None, None, None, None, None, None, 'musical', None],
#  [None, None, 'yummyy', None, None, None, 'murda', None, None, None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, None, None, None, None, None, None, 'catered', None, 'cater'],
#  ['required',
#   None,
#   'qibnqu',
#   None,
#   'knwoingly',
#   None,
#   None,
#   'messi',
#   'thecut',
#   'pye'],
#  [None, None, None, None, None, 'midcarrage', None, None, 'stavropolie', None],
#  [None,
#   None,
#   None,
#   'realdonaldtrump',
#   None,
#   'madarchod',
#   None,
#   None,
#   'ukjagfnl',
#   'realdealbillmcneal'],
#  [None, None, None, None, 'suburban', None, None, None, 'trs', None],
#  [None,
#   None,
#   None,
#   None,
#   'randi',
#   None,
#   None,
#   'totallynotrobots',
#   'suicidal',
#   None],
#  [None, None, None, None, None, 'shape', None, None, None, 'uck'],
#  [None, None, 'murda', None, None, None, None, None, 'noamnesty', 'noavail'],
#  ['removethefakeassrepublicans',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'trumpcesspool',
#   None,
#   None,
#   'rally'],
#  [None, None, None, None, None, None, None, 'peabody', None, None],
#  [None,
#   None,
#   'socialjustice',
#   'steward',
#   'nubile',
#   None,
#   'gender',
#   'senileaf',
#   'unscrew',
#   None],
#  [None, None, 'shocker', None, None, None, None, None, 'tunisi', 'summ'],
#  [None,
#   None,
#   None,
#   None,
#   'mannkibaat',
#   None,
#   None,
#   'kathuarapecase',
#   'valley',
#   None],
#  [None, None, 'scherer', None, None, 'tangible', None, None, None, None],
#  [None, None, None, None, None, None, None, 'somethingigetalot', None, None],
#  [None,
#   None,
#   'suppporter',
#   'sinneed',
#   'ohin',
#   None,
#   None,
#   'recreate',
#   None,
#   None],
#  ['prevarication',
#   None,
#   None,
#   'shivering',
#   None,
#   None,
#   None,
#   'shitjamiesaysatoneam',
#   'thomson',
#   None],
#  [None, None, None, 'sanwara', None, None, None, None, 'nimbus', None],
#  [None, None, None, None, None, None, None, None, 'stephenking', 'yoga'],
#  [None, None, 'tiktokhot', None, None, 'zepplin', None, None, None, None],
#  [None, None, None, None, None, None, None, None, None, None],
#  [None, None, 'coating', None, None, None, None, 'talkcontribs', None, None],
#  [None,
#   None,
#   None,
#   'strapping',
#   None,
#   None,
#   'zaaaammnn',
#   None,
#   'usbecause',
#   'sense'],
#  ['thin', None, None, 'seha', None, None, 'refugeescrisis', None, None, None],
#  [None,
#   None,
#   'herb',
#   'brasil',
#   None,
#   None,
#   'wikiprostitute',
#   None,
#   'maam',
#   None],
#  [None, None, None, None, None, None, None, 'signpost', None, None],
#  [None, None, None, None, None, None, None, None, None, None],
#  ['muhajirs',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'yellowtards',
#   'hypothetical',
#   None,
#   None],
#  ['scripted', None, None, None, 'tko', None, None, None, None, None],
#  ['stabbing', 'nullify', None, None, None, None, None, None, None, None],
#  [None, 'purefoy', None, None, None, None, 'suboxone', None, None, None],
#  [None, None, None, 'mouf', None, 'mercilessly', None, None, None, 'railway'],
#  [None, None, None, None, None, None, 'murda', None, 'urba', None],
#  ['erasure', None, 'islamasylum', None, None, 'dyer', None, None, None, None],
#  [None, None, None, None, None, 'nocontext', 'moth', None, 'terrorize', None],
#  ['garrcia',
#   'adverse',
#   None,
#   None,
#   None,
#   None,
#   None,
#   'stablegenius',
#   None,
#   'strive'],
#  [None, None, None, 'phentype', None, None, None, None, None, None],
#  ['sucksfrozen',
#   None,
#   None,
#   'resolutely',
#   'halal',
#   None,
#   None,
#   'sesspool',
#   None,
#   None],
#  [None, None, None, None, None, None, 'squatting', None, None, 'whoppin'],
#  [None, 'loooosseeerrr', None, None, None, None, None, None, 'onee', None],
#  ['namesake',
#   'bloodorimym',
#   'butch',
#   'botted',
#   'soooooooo',
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None,
#   None,
#   None,
#   'girbaud',
#   'irriational',
#   None,
#   None,
#   None,
#   None,
#   'mouthful'],
#  [None, 'murda', None, 'yoooou', None, None, None, None, 'sexiest', None],
#  [None,
#   'pau',
#   'scully',
#   None,
#   None,
#   None,
#   'paul',
#   'suicidal',
#   None,
#   'slumdog'],
#  ['pressed',
#   None,
#   None,
#   'shouted',
#   None,
#   None,
#   'revertss',
#   None,
#   None,
#   'serna'],
#  [None, None, None, None, None, None, None, None, None, 'ramadan'],
#  [None, None, None, None, 'rdtm', None, None, 'yeahh', 'secretly', None],
#  [None, None, None, None, None, None, None, 'mommie', None, None],
#  [None, None, None, 'fitzcarraldo', None, None, None, None, None, None],
#  [None, None, None, None, None, None, 'monopolize', None, None, None],
#  [None, None, 'flicked', None, None, None, None, None, None, None],
#  ['sdjasf', None, None, None, None, None, 'malusia', None, None, None],
#  [None,
#   'shoulda',
#   'ogelizabeth',
#   'lvl',
#   None,
#   'uknow',
#   None,
#   None,
#   'theyello',
#   None],
#  [None, None, None, None, None, None, None, 'semetic', None, None],
#  ['freeballoutpartypart',
#   'stupidity',
#   None,
#   None,
#   None,
#   'rdh',
#   None,
#   'unthinking',
#   None,
#   None],
#  [None,
#   None,
#   None,
#   'streamable',
#   None,
#   'draggn',
#   'xvi',
#   None,
#   None,
#   'lastqueencyn'],
#  ['pot',
#   'fuckkkkk',
#   'trumpforjail',
#   'pretzel',
#   None,
#   None,
#   'tafsir',
#   None,
#   None,
#   'notcome'],
#  ['retatded',
#   None,
#   None,
#   'mondaymorning',
#   None,
#   None,
#   None,
#   'surveillance',
#   None,
#   None],
#  [None, 'kill', None, None, 'aquaman', None, None, None, None, 'kil'],
#  [None, None, None, 'tix', None, None, None, None, 'wats', None],
#  [None,
#   'murda',
#   'racialark',
#   None,
#   'cantrell',
#   None,
#   'utica',
#   None,
#   None,
#   None],
#  [None,
#   None,
#   None,
#   'txw',
#   'dalits',
#   'neantherthals',
#   'creepypence',
#   None,
#   None,
#   None],
#  [None, 'shortcoming', 'prelude', None, None, 'nks', None, None, None, None],
#  ['murda', None, None, None, None, None, None, None, 'nazism', None],
#  [None, None, None, 'maoist', None, None, 'okla', 'okcupid', None, None],
#  [None, None, None, None, 'whheeet', None, None, None, None, None],
#  ['cab', 'bdt', None, None, None, None, None, None, None, None],
#  [None, None, 'nodefense', None, None, 'lwn', None, 'mfka', None, 'mirrored'],
#  ['slithering', None, None, None, None, None, None, None, None, None],
#  [None, None, None, None, 'nenakelly', None, 'mansize', None, 'upppp', None],
#  [None, None, None, None, None, None, None, None, None, None],
#  ['murda',
#   'shittyaskscience',
#   'ocra',
#   'tailback',
#   'shitn',
#   None,
#   'youresilly',
#   None,
#   None,
#   'uzair'],
#  [None,
#   None,
#   None,
#   None,
#   'peaktrans',
#   'peanut',
#   'moneyless',
#   None,
#   None,
#   None],
#  [None, 'crikey', None, None, None, None, 'offff', None, None, None],
#  ['atthesamedamntime',
#   None,
#   'morrow',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  [None,
#   'meteos',
#   'necro',
#   'rajivgandhichorhai',
#   None,
#   None,
#   None,
#   'nathanshotdogeatingcontest',
#   None,
#   None],
#  [None, 'mansize', None, None, None, 'simeone', None, None, None, None],
#  [None, None, 'met', None, 'mislabeled', None, None, 'pelase', None, None],
#  [None, None, None, None, None, 'murda', None, None, None, None],
#  ...]

# %%
df_tfidf['top10'] = [[reverse_vocab.get(item) for item in row] for row in tfidf_max_n]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-273-0e23ee52a674> in <module>
# ----> 1 df_tfidf['top10'] = [[reverse_vocab.get(item) for item in row] for row in tfidf_max_n]
#
# ~\Miniconda3_nov\envs\nlp2\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ~\Miniconda3_nov\envs\nlp2\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# ~\Miniconda3_nov\envs\nlp2\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3897
#    3898             # turn me into an ndarray
# -> 3899             value = sanitize_index(value, self.index)
#    3900             if not isinstance(value, (np.ndarray, Index)):
#    3901                 if isinstance(value, list) and len(value) > 0:
#
# ~\Miniconda3_nov\envs\nlp2\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index)
#     749     """
#     750     if len(data) != len(index):
# --> 751         raise ValueError(
#     752             "Length of values "
#     753             f"({len(data)}) "
#
# ValueError: Length of values (11314) does not match length of index (17)

# %%
df_tfidf['top10']
# Out:
#           aa       aaa  aaaaaaaaaa  aaaaaaaaaah  aaaaaaaaand  aaaaaaaaayo  \
# 0   0.000000  0.000000    0.000000     0.000000     0.000000     0.000000
# 1   0.000000  0.000000    0.000000     0.000000     0.000000     0.000000
# 2   0.000000  0.000000    0.000000     0.000000     0.000000     0.000000
# 3   0.000000  0.000000    0.000458     0.002152     0.000000     0.000458
# 4   0.000000  0.000000    0.000000     0.000000     0.000000     0.000000
# 5   0.000000  0.000349    0.000000     0.000156     0.000000     0.000000
# 6   0.000000  0.000000    0.000000     0.000000     0.000000     0.000000
# 7   0.000000  0.000000    0.000000     0.000000     0.000000     0.000000
# 8   0.000000  0.000000    0.000000     0.000000     0.002321     0.000000
# 9   0.000000  0.000000    0.000000     0.000000     0.000000     0.000000
# 10  0.000000  0.000000    0.000000     0.000000     0.000000     0.000000
# 11  0.000000  0.000000    0.000000     0.000000     0.000000     0.000000
# 12  0.000000  0.000000    0.000000     0.000000     0.000000     0.000000
# 13  0.000000  0.000000    0.000000     0.000000     0.000000     0.000000
# 14  0.000229  0.000399    0.000000     0.000179     0.000000     0.000000
# 15  0.000000  0.000000    0.000000     0.000000     0.000000     0.000000
# 16  0.000000  0.000000    0.000000     0.000000     0.000000     0.000000
#
#     aaaaaaand   aaaaand  aaaahhhh  aaaannnnyyyywwwwhhhheeeerrrreeee  ...  \
# 0    0.000000  0.000000  0.000000                            0.0000  ...
# 1    0.000000  0.000000  0.002073                            0.0000  ...
# 2    0.000000  0.000000  0.000000                            0.0000  ...
# 3    0.000000  0.001600  0.000000                            0.0000  ...
# 4    0.000000  0.000000  0.000000                            0.0000  ...
# 5    0.000000  0.000000  0.000000                            0.0002  ...
# 6    0.000000  0.000000  0.000000                            0.0000  ...
# 7    0.000000  0.000000  0.000000                            0.0000  ...
# 8    0.000000  0.000000  0.000000                            0.0000  ...
# 9    0.000000  0.000000  0.000000                            0.0000  ...
# 10   0.000000  0.000000  0.000000                            0.0000  ...
# 11   0.000000  0.000000  0.000000                            0.0000  ...
# 12   0.000000  0.000000  0.000000                            0.0000  ...
# 13   0.001167  0.001019  0.000000                            0.0000  ...
# 14   0.000000  0.000000  0.000000                            0.0000  ...
# 15   0.000000  0.000000  0.000000                            0.0000  ...
# 16   0.000000  0.000000  0.000000                            0.0000  ...
#
#         zyzz    zzffpp       zzh    zzinhl     zzxth  zzyhgejom      zzzz  \
# 0   0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000331
# 1   0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 2   0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 3   0.000000  0.000000  0.000000  0.000000  0.000458   0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.006441
# 5   0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 6   0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 7   0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 8   0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 9   0.000769  0.000769  0.000769  0.000769  0.000000   0.000769  0.000000
# 10  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 11  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000739
# 12  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 13  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000832
# 14  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 15  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 16  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
#
#       zzzzzz   zzzzzzz  zzzzzzzzzzzzzzzzz
# 0   0.000000  0.000000           0.000000
# 1   0.000000  0.000000           0.000000
# 2   0.000000  0.000000           0.000000
# 3   0.000000  0.000000           0.000000
# 4   0.000000  0.000000           0.000000
# 5   0.000000  0.000000           0.000156
# 6   0.000000  0.000000           0.000000
# 7   0.000000  0.000000           0.000000
# 8   0.002321  0.000000           0.000000
# 9   0.000000  0.000000           0.000000
# 10  0.000000  0.000000           0.000000
# 11  0.000000  0.000000           0.000000
# 12  0.000000  0.000000           0.000236
# 13  0.000000  0.000000           0.000000
# 14  0.000000  0.000229           0.000179
# 15  0.000000  0.000000           0.000000
# 16  0.000000  0.000000           0.000000
#
# [17 rows x 48922 columns]

# %%
X_tf_idf.shape
feature_names.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-254-019c4d4b706a> in <module>
#       1 X_tf_idf.shape
# ----> 2 feature_names.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
tfIdfVectorizer.transform(['fuck'])
# Out:
# <1x48922 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>

# %%
tfidf_array = tfIdf.toarray()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-217-668f4d842964> in <module>
# ----> 1 tfidf_array = tfIdf.toarray()
#
# ~\Miniconda3_nov\envs\nlp2\lib\site-packages\scipy\sparse\compressed.py in toarray(self, order, out)
#    1029         if out is None and order is None:
#    1030             order = self._swap('cf')[0]
# -> 1031         out = self._process_toarray_args(order, out)
#    1032         if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1033             raise ValueError('Output array must be C or F contiguous')
#
# ~\Miniconda3_nov\envs\nlp2\lib\site-packages\scipy\sparse\base.py in _process_toarray_args(self, order, out)
#    1200             return out
#    1201         else:
# -> 1202             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1203
#    1204
#
# MemoryError: Unable to allocate 28.3 GiB for an array with shape (77668, 48922) and data type float64

# %% [markdown]
# ### word2vec embeddings (pretrained) visualisation

# %%
n_significant_words = 10
word_clusters, embedding_clusters = get_word_embeddings(unique_labels, df_labels, 'n_most_freq_words', model_gn_word2vec, n_significant_words)
# Out:
# ['faggot', 'cuck', 'subreddit', 'neighbour', 'fairooz', 'daesh', 'microbrain', 'faggot', 'noogoo', 'totesmessenger', 'redditors', 'formspring', 'faggot', 'faggot', 'fucksex', 'yourselfgo', 'buttsecks', 'mothjer', 'bastered', 'assad', 'offfuck', 'hanibal', 'supertr', 'rvv', 'youcaltlas', 'beavis', 'faggot', 'caltlas', 'faggot', 'bunksteve', 'ancestryfuck', 'centraliststupid', 'bleachanhero', 'jforget', 'couriano', 'faggot', 'trumpisatraitor', 'shameonicc', 'doctorsfightback', 'borisjohnsonshouldnotbepm', 'dhonikeepstheglove', 'fucktrump', 'gandinaaliabuse', 'cwc', 'borisjohnson', 'whitegenocide', 'whitelivesmatter', 'whitepower', 'antiwhite', 'tcot', 'faggot', 'niggah', 'aint', 'mkr', 'notsexist', 'womenagainstfeminism', 'faggot', 'fucksex', 'yourselfgo', 'mothjer', 'offfuck', 'hanibal', 'assad', 'criminalwar', 'bunksteve', 'marcolfuck', 'notrhbysouthbanof', 'securityfuck', 'veggietales', 'ancestryfuck', 'shitfuck', 'bradbury', 'bleachanhero', 'bitchmattythewhite', 'haahhahahah', 'faggot', 'yourselfgo', 'mothjer', 'bastered', 'assad', 'fggt', 'hanibal', 'faggot', 'totesmessenger', 'redditors', 'subreddit', 'fucktrump', 'trumpisatraitor', 'resisttrump', 'shameonicc', 'johnmccainday', 'impeachtrump', 'impeachtrumpnow', 'fuckthegop', 'borisjohnsonshouldnotbepm', 'traitortrump', 'cwc']

# %%
displayDF(word_clusters, unique_labels)
# Out:
#       slur  hostile    racist homophobic cyberbullying    obscene   threat  \
# 0     cunt   people     islam    fucking         bitch       fuck      die
# 1  fucking    woman    muslim       fuck          fake       suck       as
# 2     fuck    black  mohammed      child          like       shit     kill
# 3    idiot     like  religion       shit           get    fucking    going
# 4     shit    white       isi     nigger       fucking         as    block
# 5     dumb  fucking       jew    hillary          shit     nigger     fuck
# 6      lol     love   prophet     reddit          know      bitch     must
# 7    bitch      men     quran    clinton          fuck       cunt      jim
# 8       as  country    people     people            as  wikipedia     wale
# 9    pussy    would      like      trump          stop       like  fucking
#
#   identity_hate hateful harassment offensive  sexist severe_toxic   vulgar  \
# 0        nigger   bitch        jew     bitch  sexist         fuck     shit
# 1           jew    like    fucking       hoe   woman         suck     hell
# 2           fat   nigga      white      like    girl           as     damn
# 3           gay  nigger     muslim     pussy     kat         shit     fuck
# 4          fuck  people       cunt     nigga  female        bitch       as
# 5           die   white       like        as    like      fucking    bitch
# 6       fucking      as     people       got    call          die     like
# 7         nigga     get     hitler      fuck     men         cunt  fucking
# 8          suck   trump   feminist       get   think       nigger      get
# 9          huge    fuck     nigger      shit     get         cock      one
#
#     insult    abuse    profane
# 0     fuck     fuck       fuck
# 1     suck  fucking   dickhead
# 2   nigger    child      trump
# 3  fucking     shit    fucking
# 4       as      mod  douchebag
# 5    bitch  hillary       like
# 6      fat  clinton       shit
# 7     shit   reddit     doctor
# 8     cunt    trump        get
# 9     like   people    twitter

# %%
plotTSNE(f"Word Hierarchy - Word2Vec [t-SNE] {n_significant_words} words", unique_labels, word_clusters, embedding_clusters, 
         f"WordHierarchy - word2vec - t-SNE {n_significant_words} words.png")

# %%
plotMDS(f"Word Hierarchy - Word2Vec [MDS] {n_significant_words} words", unique_labels, word_clusters, embedding_clusters, 
        f"WordHierarchy - word2vec - MDS {n_significant_words} words.png")

# %%
plotPCA(f"Word Hierarchy - Word2Vec [PCA] {n_significant_words} words", unique_labels, word_clusters, embedding_clusters, 
        f"WordHierarchy - word2vec - PCA {n_significant_words} words.png")

# %% [markdown]
# ### Glove embeddings (pretrained) visualisations

# %%
n_significant_words = 10
word_clusters, embedding_clusters = get_word_embeddings(unique_labels, df_labels, 'n_most_freq_words', model_gn_glove, n_significant_words)
# Out:
# ['dumbass', 'cuck', 'lmao', 'subreddit', 'fairooz', 'daesh', 'microbrain', 'noogoo', 'totesmessenger', 'redditors', 'youu', 'dickhead', 'fucksex', 'yourselfgo', 'cocksucker', 'buttsecks', 'mothjer', 'bastered', 'offfuck', 'hanibal', 'supertr', 'rvv', 'youcaltlas', 'caltlas', 'bunksteve', 'ancestryfuck', 'centraliststupid', 'bleachanhero', 'cocksucking', 'jforget', 'couriano', 'trumpisatraitor', 'shameonicc', 'doctorsfightback', 'borisjohnsonshouldnotbepm', 'dhonikeepstheglove', 'fucktrump', 'gandinaaliabuse', 'douchebag', 'borisjohnson', 'whitegenocide', 'whitelivesmatter', 'whitepower', 'antiwhite', 'tcot', 'lmao', 'niggah', 'notsexist', 'womenagainstfeminism', 'fucksex', 'yourselfgo', 'cocksucker', 'mothjer', 'offfuck', 'hanibal', 'dickhead', 'criminalwar', 'bunksteve', 'cocksucking', 'marcolfuck', 'fack', 'notrhbysouthbanof', 'securityfuck', 'ancestryfuck', 'shitfuck', 'bleachanhero', 'bitchmattythewhite', 'haahhahahah', 'dickhead', 'yourselfgo', 'cocksucker', 'mothjer', 'bastered', 'fggt', 'hanibal', 'totesmessenger', 'redditors', 'subreddit', 'fucktrump', 'dickhead', 'douchebag', 'trumpisatraitor', 'resisttrump', 'shameonicc', 'johnmccainday', 'impeachtrump', 'impeachtrumpnow', 'fuckthegop', 'borisjohnsonshouldnotbepm', 'traitortrump']

# %%
displayDF(word_clusters, unique_labels)
# Out:
#       slur  hostile    racist homophobic cyberbullying    obscene   threat  \
# 0     cunt   people     islam    fucking         bitch       fuck      die
# 1  fucking    woman    muslim       fuck          fake       suck       as
# 2     fuck    black  mohammed      child          like       shit     kill
# 3    idiot     like  religion     faggot           get    fucking    going
# 4     shit    white       isi       shit       fucking         as    block
# 5     dumb  fucking       jew     nigger          shit     nigger     fuck
# 6      lol     love   prophet    hillary          know      bitch     must
# 7    bitch      men     quran     reddit          fuck     faggot      jim
# 8       as  country    people    clinton            as       cunt     wale
# 9    pussy    would      like     people          stop  wikipedia  fucking
#
#   identity_hate hateful harassment offensive  sexist severe_toxic   vulgar  \
# 0        nigger   bitch        jew     bitch  sexist         fuck     shit
# 1           jew  faggot    fucking       hoe     mkr         suck     hell
# 2           fat    like      white      like   woman           as     damn
# 3           gay   nigga     muslim     pussy    girl         shit     fuck
# 4          fuck  nigger       cunt     nigga     kat       faggot       as
# 5           die  people       like        as  female        bitch    bitch
# 6        faggot   white     people       got    like      fucking     like
# 7       fucking      as     hitler      fuck    call          die  fucking
# 8         nigga     get   feminist       get     men         cunt      get
# 9          suck   trump     nigger      shit   think       nigger      one
#
#     insult    abuse  profane
# 0     fuck     fuck     fuck
# 1     suck  fucking    trump
# 2   nigger    child  fucking
# 3  fucking     shit     like
# 4   faggot      mod     shit
# 5       as  hillary   doctor
# 6    bitch  clinton      get
# 7      fat   reddit  twitter
# 8     shit    trump   resist
# 9     cunt   people    world

# %%
plotTSNE(f"Word Hierarchy - Glove [t-SNE] {n_significant_words} words ", unique_labels, word_clusters,embedding_clusters, 
         f"WordHierarchy - Glove - t-SNE {n_significant_words} words.png")

# %%
plotMDS(f"Word Hierarchy - Glove [MDS] {n_significant_words} words ",unique_labels, word_clusters, embedding_clusters, 
        f"WordHierarchy - Glove - MDS {n_significant_words} words .png")

# %%
plotPCA(f"Word Hierarchy - Glove [PCA] {n_significant_words} words",unique_labels, word_clusters, embedding_clusters,
        f"WordHierarchy - Glove - PCA {n_significant_words} words.png")

# %% [markdown]
# ### fasttext embedings (pretrained) visualisations

# %%
# Run first time only to download model
#import fasttext.util
#fasttext.util.download_model('en', if_exists='ignore')  # English
#ft = fasttext.load_model('cc.en.300.bin')

# Chaya used: https://fasttext.cc/docs/en/crawl-vectors.html
# It includes both Common Crawl and Wikipedia - file cc.en.300.bin.

model_gn = load_facebook_vectors("cc.en.300.bin")

# %%
n_significant_words=10
word_clusters, embedding_clusters = get_word_embeddings(unique_labels, df_labels, 'n_most_freq_words', model_gn_glove, n_significant_words)
# Out:
# ['dumbass', 'cuck', 'lmao', 'subreddit', 'fairooz', 'daesh', 'microbrain', 'noogoo', 'totesmessenger', 'redditors', 'youu', 'dickhead', 'fucksex', 'yourselfgo', 'cocksucker', 'buttsecks', 'mothjer', 'bastered', 'offfuck', 'hanibal', 'supertr', 'rvv', 'youcaltlas', 'caltlas', 'bunksteve', 'ancestryfuck', 'centraliststupid', 'bleachanhero', 'cocksucking', 'jforget', 'couriano', 'trumpisatraitor', 'shameonicc', 'doctorsfightback', 'borisjohnsonshouldnotbepm', 'dhonikeepstheglove', 'fucktrump', 'gandinaaliabuse', 'douchebag', 'borisjohnson', 'whitegenocide', 'whitelivesmatter', 'whitepower', 'antiwhite', 'tcot', 'lmao', 'niggah', 'notsexist', 'womenagainstfeminism', 'fucksex', 'yourselfgo', 'cocksucker', 'mothjer', 'offfuck', 'hanibal', 'dickhead', 'criminalwar', 'bunksteve', 'cocksucking', 'marcolfuck', 'fack', 'notrhbysouthbanof', 'securityfuck', 'ancestryfuck', 'shitfuck', 'bleachanhero', 'bitchmattythewhite', 'haahhahahah', 'dickhead', 'yourselfgo', 'cocksucker', 'mothjer', 'bastered', 'fggt', 'hanibal', 'totesmessenger', 'redditors', 'subreddit', 'fucktrump', 'dickhead', 'douchebag', 'trumpisatraitor', 'resisttrump', 'shameonicc', 'johnmccainday', 'impeachtrump', 'impeachtrumpnow', 'fuckthegop', 'borisjohnsonshouldnotbepm', 'traitortrump']

# %%
plotTSNE(f"Word Hierarchy - Fasttext [t-SNE] {n_significant_words} words ", unique_labels, word_clusters,embedding_clusters, 
         f"WordHierarchy - Fasttext - t-SNE {n_significant_words} words.png")

# %%
plotMDS(f"Word Hierarchy - Fasttext [MDS] {n_significant_words} words ",unique_labels, word_clusters, embedding_clusters, 
        f"WordHierarchy - Fasttext - MDS {n_significant_words} words .png")

# %%
plotPCA(f"Word Hierarchy - Fasttext [PCA] {n_significant_words} words",unique_labels, word_clusters, embedding_clusters,
        f"WordHierarchy - Fasttext - PCA {n_significant_words} words.png")
